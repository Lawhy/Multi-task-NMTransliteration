# %%
from mnmt.encoder import BasicEncoder
from mnmt.decoder import BasicFeedForwardDecoder
from mnmt.decoder import GreedyDecoder
from mnmt.attention import AdditiveAttention
from mnmt.decoder import BridgeLayer
from mnmt.model import Seq2Seq, Seq2MultiSeq
from mnmt.datasets import *
from mnmt.inputter import ArgsFeeder
from mnmt.inputter import ModuleArgsFeeder
from mnmt.trainer.utils import *
from mnmt.trainer import Trainer
import torch.nn as nn
import sys
# Out:
# Loading DICT dataset...
# Loading the Dataset into the container...
# Field names: ['en', 'ch', 'pinyin_str', 'pinyin_char']
# Data sizes: [(Train, 46620), (Valid, 5828), (Test, 5828)]
# The first example of the training data is:
# en :  ['k', 'a', 'r', 't', 'm', 'a', 'n']
# ch :  ['卡', '特', '曼']
# pinyin_str :  ['ka', 'te', 'man']
# pinyin_char :  ['k', 'a', 't', 'e', 'm', 'a', 'n']
# Loading NEWS dataset...
# Loading the Dataset into the container...
# Field names: ['en', 'ch', 'pinyin_str', 'pinyin_char']
# Data sizes: [(Train, 81252), (Valid, 513), (Test, 1000)]
# The first example of the training data is:
# en :  ['k', 'u', 's', 'i', 'c', 'k']
# ch :  ['库', '西', '克']
# pinyin_str :  ['ku', 'xi', 'ke']
# pinyin_char :  ['k', 'u', 'x', 'i', 'k', 'e']

# %%
def set_up_args(data_container, exp_num):
    build_vocabs(data_container, dict_min_freqs={'en': 1, 'ch': 1, 'pinyin_str': 1, 'pinyin_char': 1})
    for name, field in data_container.fields:
        if name == 'en':
            input_dim = len(field.vocab)
            src_pad_idx = field.vocab.stoi[field.pad_token]
        elif name == 'ch':
            output_dim = len(field.vocab)
            trg_pad_idx = field.vocab[field.pad_token]

    enc_args_feeder = ModuleArgsFeeder(input_dim=input_dim, embedding_dim=256, hidden_dim=512,
                                       embedding_dropout=0.1, rnn_type='LSTM',
                                       num_layers=2, rnn_dropout=0.2)
    dec_args_feeder = ModuleArgsFeeder(input_dim=output_dim, embedding_dim=256, hidden_dim=512,
                                       embedding_dropout=0.1, rnn_type='LSTM',
                                       num_layers=2, rnn_dropout=0.2)
    dec_args_feeder_aux = ModuleArgsFeeder(input_dim=output_dim, embedding_dim=128, hidden_dim=256,
                                       embedding_dropout=0.1, rnn_type='LSTM',
                                       num_layers=2, rnn_dropout=0.1)
    return ArgsFeeder(enc_args_feeder, [dec_args_feeder, dec_args_feeder_aux],
                      batch_size=64, src_pad_idx=src_pad_idx, trg_pad_idx=trg_pad_idx,
                      optim_choice='Adam', learning_rate=0.003, decay_patience=0,
                      lr_decay_factor=0.9, valid_criterion='ACC', early_stopping_patience=100,
                      total_epochs=100, report_interval=50, exp_num=exp_num, multi_task_ratio=66, data_container=data_container,
                      src_lang='en', trg_lang='ch', auxiliary_name='pinyin_str', quiet_translate=True,
                      valid_out_path=f"experiments/exp{exp_num}/valid.out", test_out_path=f"experiments/exp{exp_num}/test.out",
                      beam_size=1)


def test_seq2seq(args_feeder):
    
    decoder_args_feeder = args_feeder.decoder_args_feeders[0]
    decoder_args_feeder_aux = args_feeder.decoder_args_feeders[1]
    
    encoder = BasicEncoder(args_feeder)
    
    feed_forward_decoder = \
        BasicFeedForwardDecoder(args_feeder,
                                AdditiveAttention(encoder_hidden_dim=args_feeder.encoder_args_feeder.hidden_dim,
                                                  decoder_hidden_dim=decoder_args_feeder.hidden_dim), 
                                                  decoder_index=0)
    feed_forward_decoder_aux = \
            BasicFeedForwardDecoder(args_feeder,
                                    AdditiveAttention(encoder_hidden_dim=args_feeder.encoder_args_feeder.hidden_dim,
                                                      decoder_hidden_dim=decoder_args_feeder_aux.hidden_dim), 
                                                      decoder_index=1)
                                
    bridge_layer = BridgeLayer(encoder_hidden_dim=args_feeder.encoder_args_feeder.hidden_dim,
                               decoder_hidden_dim=decoder_args_feeder.hidden_dim,
                               num_of_states=2)
    bridge_layer_aux = BridgeLayer(encoder_hidden_dim=args_feeder.encoder_args_feeder.hidden_dim,
                                   decoder_hidden_dim=decoder_args_feeder_aux.hidden_dim,
                                   num_of_states=2)
                                
    decoder = GreedyDecoder(feed_forward_decoder, bridge_layer, device=args_feeder.device)
    decoder_aux = GreedyDecoder(feed_forward_decoder_aux, bridge_layer_aux, device=args_feeder.device)
                                
    model = Seq2MultiSeq(args_feeder, encoder, 
                         nn.ModuleList([decoder, decoder_aux]), 
                         teacher_forcing_ratio=0.8).to(args_feeder.device)
    return model


if __name__ == '__main__':
    set_reproducibility(seed=1234)
    mtrs = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]
    aux_lang = "pinyin_char"  # pinyin_str, pinyin_char
    mtrs.reverse()
    try:
        # DICT Multi 
        dict_dataset = DICT['data_container']
        for i in range(6, len(mtrs)):
            i += 1
            seq2seq_args_feeder = set_up_args(dict_dataset, exp_num=20 + i)
            seq2seq_args_feeder.multi_task_ratio = mtrs[i-1]
            seq2seq_args_feeder.auxiliary_name = aux_lang
            test_model = test_seq2seq(seq2seq_args_feeder)
            test_trainer = Trainer(seq2seq_args_feeder, test_model)
            test_trainer.run(burn_in_epoch=0)
            test_trainer.best_model_output()
        # NEWS Multi
        news_dataset = NEWS['data_container']
        for i in range(len(mtrs)):
            i += 1
            seq2seq_args_feeder = set_up_args(news_dataset, exp_num=30 + i)
            seq2seq_args_feeder.multi_task_ratio = mtrs[i-1]
            seq2seq_args_feeder.auxiliary_name = aux_lang
            test_model = test_seq2seq(seq2seq_args_feeder)
            test_trainer = Trainer(seq2seq_args_feeder, test_model)
            test_trainer.run(burn_in_epoch=15)
            test_trainer.best_model_output(test_ref_dict=NEWS['test-set-dict'])
    except KeyboardInterrupt:
        print("Exiting loop")
# Out:
# The current device for PyTorch is cuda
# Seq2MultiSeq(
#   (encoder): BasicEncoder(
#     (embedding): Sequential(
#       (0): Embedding(30, 256)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.2, bidirectional=True)
#   )
#   (decoder_list): ModuleList(
#     (0): GreedyDecoder(
#       (feed_forward_decoder): BasicFeedForwardDecoder(
#         (attention): AdditiveAttention(
#           (additive_mapping): Linear(in_features=1536, out_features=512, bias=True)
#           (v): Linear(in_features=512, out_features=1, bias=False)
#         )
#         (embedding): Sequential(
#           (0): Embedding(437, 256)
#           (1): Dropout(p=0.1, inplace=False)
#         )
#         (rnn): LSTM(1280, 512, num_layers=2, dropout=0.2)
#         (prediction): Sequential(
#           (0): Linear(in_features=1792, out_features=437, bias=True)
#           (1): LogSoftmax()
#         )
#       )
#       (bridge_layer): BridgeLayer(
#         (bridge_layer): ModuleList(
#           (0): Linear(in_features=1024, out_features=512, bias=True)
#           (1): Linear(in_features=1024, out_features=512, bias=True)
#         )
#       )
#     )
#     (1): GreedyDecoder(
#       (feed_forward_decoder): BasicFeedForwardDecoder(
#         (attention): AdditiveAttention(
#           (additive_mapping): Linear(in_features=1280, out_features=256, bias=True)
#           (v): Linear(in_features=256, out_features=1, bias=False)
#         )
#         (embedding): Sequential(
#           (0): Embedding(437, 128)
#           (1): Dropout(p=0.1, inplace=False)
#         )
#         (rnn): LSTM(1152, 256, num_layers=2, dropout=0.1)
#         (prediction): Sequential(
#           (0): Linear(in_features=1408, out_features=437, bias=True)
#           (1): LogSoftmax()
#         )
#       )
#       (bridge_layer): BridgeLayer(
#         (bridge_layer): ModuleList(
#           (0): Linear(in_features=1024, out_features=256, bias=True)
#           (1): Linear(in_features=1024, out_features=256, bias=True)
#         )
#       )
#     )
#   )
# )
# The model has 21,463,914 trainable parameters
# Running multi-task experiment...
# Renew Evaluation Records in the Burning Phase...
# [Train]: Current Teacher Forcing Ratio: 0.800
# [Epoch: 0][#examples: 3200/46620][#steps: 50]
# 	Train Loss: 3.721 | Train PPL:  41.306 | lr: 3.000e-03
# [Epoch: 0][#examples: 6400/46620][#steps: 100]
# 	Train Loss: 3.497 | Train PPL:  33.033 | lr: 3.000e-03
# [Epoch: 0][#examples: 9600/46620][#steps: 150]
# 	Train Loss: 3.369 | Train PPL:  29.056 | lr: 3.000e-03
# [Epoch: 0][#examples: 12800/46620][#steps: 200]
# 	Train Loss: 3.255 | Train PPL:  25.924 | lr: 3.000e-03
# [Epoch: 0][#examples: 16000/46620][#steps: 250]
# 	Train Loss: 3.100 | Train PPL:  22.200 | lr: 3.000e-03
# [Epoch: 0][#examples: 19200/46620][#steps: 300]
# 	Train Loss: 2.908 | Train PPL:  18.313 | lr: 3.000e-03
# [Epoch: 0][#examples: 22400/46620][#steps: 350]
# 	Train Loss: 2.686 | Train PPL:  14.670 | lr: 3.000e-03
# [Epoch: 0][#examples: 25600/46620][#steps: 400]
# 	Train Loss: 2.481 | Train PPL:  11.952 | lr: 3.000e-03
# [Epoch: 0][#examples: 28800/46620][#steps: 450]
# 	Train Loss: 2.299 | Train PPL:   9.965 | lr: 3.000e-03
# [Epoch: 0][#examples: 32000/46620][#steps: 500]
# 	Train Loss: 2.140 | Train PPL:   8.503 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 2816/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 2028/5828
#
# ---------------------------------------
# [Epoch: 0][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.969 | Val. Acc: 0.483 | Val. PPL:   2.634
# 	 BEST. Val. Loss: 0.969 | BEST. Val. Acc: 0.483 | Val. Loss: 0.969 | BEST. Val. Epoch: 0 | BEST. Val. Step: 500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.348
# ---------------------------------------
#
# [Epoch: 0][#examples: 35200/46620][#steps: 550]
# 	Train Loss: 2.006 | Train PPL:   7.434 | lr: 3.000e-03
# [Epoch: 0][#examples: 38400/46620][#steps: 600]
# 	Train Loss: 1.891 | Train PPL:   6.627 | lr: 3.000e-03
# [Epoch: 0][#examples: 41600/46620][#steps: 650]
# 	Train Loss: 1.789 | Train PPL:   5.985 | lr: 3.000e-03
# [Epoch: 0][#examples: 44800/46620][#steps: 700]
# 	Train Loss: 1.698 | Train PPL:   5.465 | lr: 3.000e-03
# [VAL]: The number of correct predictions (main-task (multi)): 3356/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 2995/5828
#
# ---------------------------------------
# [Epoch: 0][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.785 | Val. Acc: 0.576 | Val. PPL:   2.193
# 	 BEST. Val. Loss: 0.785 | BEST. Val. Acc: 0.576 | Val. Loss: 0.785 | BEST. Val. Epoch: 0 | BEST. Val. Step: 729
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.514
# ---------------------------------------
#
# Epoch: 01 | Time: 1m 26s
# 	Train Loss: 1.650 | Train PPL:   5.207
# 	 Val. Loss: 0.785 | Val. Acc: 0.576 | Val. PPL:   2.193
# [Train]: Current Teacher Forcing Ratio: 0.770
# [Epoch: 1][#examples: 1344/46620][#steps: 750]
# 	Train Loss: 0.453 | Train PPL:   1.574 | lr: 3.000e-03
# [Epoch: 1][#examples: 4544/46620][#steps: 800]
# 	Train Loss: 0.451 | Train PPL:   1.570 | lr: 3.000e-03
# [Epoch: 1][#examples: 7744/46620][#steps: 850]
# 	Train Loss: 0.452 | Train PPL:   1.571 | lr: 3.000e-03
# [Epoch: 1][#examples: 10944/46620][#steps: 900]
# 	Train Loss: 0.443 | Train PPL:   1.557 | lr: 3.000e-03
# [Epoch: 1][#examples: 14144/46620][#steps: 950]
# 	Train Loss: 0.435 | Train PPL:   1.545 | lr: 3.000e-03
# [Epoch: 1][#examples: 17344/46620][#steps: 1000]
# 	Train Loss: 0.431 | Train PPL:   1.539 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3595/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3441/5828
#
# ---------------------------------------
# [Epoch: 1][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.684 | Val. Acc: 0.617 | Val. PPL:   1.982
# 	 BEST. Val. Loss: 0.684 | BEST. Val. Acc: 0.617 | Val. Loss: 0.684 | BEST. Val. Epoch: 1 | BEST. Val. Step: 1000
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.590
# ---------------------------------------
#
# [Epoch: 1][#examples: 20544/46620][#steps: 1050]
# 	Train Loss: 0.429 | Train PPL:   1.535 | lr: 3.000e-03
# [Epoch: 1][#examples: 23744/46620][#steps: 1100]
# 	Train Loss: 0.427 | Train PPL:   1.533 | lr: 3.000e-03
# [Epoch: 1][#examples: 26944/46620][#steps: 1150]
# 	Train Loss: 0.420 | Train PPL:   1.522 | lr: 3.000e-03
# [Epoch: 1][#examples: 30144/46620][#steps: 1200]
# 	Train Loss: 0.420 | Train PPL:   1.522 | lr: 3.000e-03
# [Epoch: 1][#examples: 33344/46620][#steps: 1250]
# 	Train Loss: 0.419 | Train PPL:   1.521 | lr: 3.000e-03
# [Epoch: 1][#examples: 36544/46620][#steps: 1300]
# 	Train Loss: 0.416 | Train PPL:   1.516 | lr: 3.000e-03
# [Epoch: 1][#examples: 39744/46620][#steps: 1350]
# 	Train Loss: 0.413 | Train PPL:   1.512 | lr: 3.000e-03
# [Epoch: 1][#examples: 42944/46620][#steps: 1400]
# 	Train Loss: 0.411 | Train PPL:   1.508 | lr: 3.000e-03
# [Epoch: 1][#examples: 46144/46620][#steps: 1450]
# 	Train Loss: 0.409 | Train PPL:   1.506 | lr: 3.000e-03
# [VAL]: The number of correct predictions (main-task (multi)): 3752/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3677/5828
#
# ---------------------------------------
# [Epoch: 1][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.623 | Val. Acc: 0.644 | Val. PPL:   1.865
# 	 BEST. Val. Loss: 0.623 | BEST. Val. Acc: 0.644 | Val. Loss: 0.623 | BEST. Val. Epoch: 1 | BEST. Val. Step: 1458
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.631
# ---------------------------------------
#
# Epoch: 02 | Time: 1m 28s
# 	Train Loss: 0.409 | Train PPL:   1.505
# 	 Val. Loss: 0.623 | Val. Acc: 0.644 | Val. PPL:   1.865
# [Train]: Current Teacher Forcing Ratio: 0.740
# [Epoch: 2][#examples: 2688/46620][#steps: 1500]
# 	Train Loss: 0.299 | Train PPL:   1.349 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3814/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3782/5828
#
# ---------------------------------------
# [Epoch: 2][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.590 | Val. Acc: 0.654 | Val. PPL:   1.804
# 	 BEST. Val. Loss: 0.590 | BEST. Val. Acc: 0.654 | Val. Loss: 0.590 | BEST. Val. Epoch: 2 | BEST. Val. Step: 1500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.649
# ---------------------------------------
#
# [Epoch: 2][#examples: 5888/46620][#steps: 1550]
# 	Train Loss: 0.298 | Train PPL:   1.347 | lr: 3.000e-03
# [Epoch: 2][#examples: 9088/46620][#steps: 1600]
# 	Train Loss: 0.297 | Train PPL:   1.346 | lr: 3.000e-03
# [Epoch: 2][#examples: 12288/46620][#steps: 1650]
# 	Train Loss: 0.301 | Train PPL:   1.351 | lr: 3.000e-03
# [Epoch: 2][#examples: 15488/46620][#steps: 1700]
# 	Train Loss: 0.302 | Train PPL:   1.353 | lr: 3.000e-03
# [Epoch: 2][#examples: 18688/46620][#steps: 1750]
# 	Train Loss: 0.303 | Train PPL:   1.353 | lr: 3.000e-03
# [Epoch: 2][#examples: 21888/46620][#steps: 1800]
# 	Train Loss: 0.302 | Train PPL:   1.353 | lr: 3.000e-03
# [Epoch: 2][#examples: 25088/46620][#steps: 1850]
# 	Train Loss: 0.304 | Train PPL:   1.355 | lr: 3.000e-03
# [Epoch: 2][#examples: 28288/46620][#steps: 1900]
# 	Train Loss: 0.304 | Train PPL:   1.355 | lr: 3.000e-03
# [Epoch: 2][#examples: 31488/46620][#steps: 1950]
# 	Train Loss: 0.308 | Train PPL:   1.360 | lr: 3.000e-03
# [Epoch: 2][#examples: 34688/46620][#steps: 2000]
# 	Train Loss: 0.309 | Train PPL:   1.361 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3855/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3761/5828
#
# ---------------------------------------
# [Epoch: 2][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 99/100
# 	 Val. Loss: 0.606 | Val. Acc: 0.661 | Val. PPL:   1.834
# 	 BEST. Val. Loss: 0.590 | BEST. Val. Acc: 0.661 | Val. Loss: 0.606 | BEST. Val. Epoch: 2 | BEST. Val. Step: 2000
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.649
# ---------------------------------------
#
# [Epoch: 2][#examples: 37888/46620][#steps: 2050]
# 	Train Loss: 0.310 | Train PPL:   1.364 | lr: 3.000e-03
# [Epoch: 2][#examples: 41088/46620][#steps: 2100]
# 	Train Loss: 0.312 | Train PPL:   1.366 | lr: 3.000e-03
# [Epoch: 2][#examples: 44288/46620][#steps: 2150]
# 	Train Loss: 0.313 | Train PPL:   1.368 | lr: 3.000e-03
# [VAL]: The number of correct predictions (main-task (multi)): 3801/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3799/5828
#
# ---------------------------------------
# [Epoch: 2][Validatiing...]
# 	 Early Stopping Patience: 98/100
# 	 Val. Loss: 0.614 | Val. Acc: 0.652 | Val. PPL:   1.848
# 	 BEST. Val. Loss: 0.590 | BEST. Val. Acc: 0.661 | Val. Loss: 0.606 | BEST. Val. Epoch: 2 | BEST. Val. Step: 2000
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.652
# ---------------------------------------
#
# Epoch: 03 | Time: 1m 34s
# 	Train Loss: 0.313 | Train PPL:   1.368
# 	 Val. Loss: 0.614 | Val. Acc: 0.652 | Val. PPL:   1.848
# [Train]: Current Teacher Forcing Ratio: 0.710
# [Epoch: 3][#examples: 832/46620][#steps: 2200]
# 	Train Loss: 0.279 | Train PPL:   1.321 | lr: 2.700e-03
# [Epoch: 3][#examples: 4032/46620][#steps: 2250]
# 	Train Loss: 0.260 | Train PPL:   1.297 | lr: 2.700e-03
# [Epoch: 3][#examples: 7232/46620][#steps: 2300]
# 	Train Loss: 0.257 | Train PPL:   1.294 | lr: 2.700e-03
# [Epoch: 3][#examples: 10432/46620][#steps: 2350]
# 	Train Loss: 0.251 | Train PPL:   1.286 | lr: 2.700e-03
# [Epoch: 3][#examples: 13632/46620][#steps: 2400]
# 	Train Loss: 0.246 | Train PPL:   1.279 | lr: 2.700e-03
# [Epoch: 3][#examples: 16832/46620][#steps: 2450]
# 	Train Loss: 0.243 | Train PPL:   1.275 | lr: 2.700e-03
# [Epoch: 3][#examples: 20032/46620][#steps: 2500]
# 	Train Loss: 0.244 | Train PPL:   1.276 | lr: 2.700e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3877/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3875/5828
#
# ---------------------------------------
# [Epoch: 3][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.570 | Val. Acc: 0.665 | Val. PPL:   1.768
# 	 BEST. Val. Loss: 0.570 | BEST. Val. Acc: 0.665 | Val. Loss: 0.570 | BEST. Val. Epoch: 3 | BEST. Val. Step: 2500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.665
# ---------------------------------------
#
# [Epoch: 3][#examples: 23232/46620][#steps: 2550]
# 	Train Loss: 0.245 | Train PPL:   1.277 | lr: 2.700e-03
# [Epoch: 3][#examples: 26432/46620][#steps: 2600]
# 	Train Loss: 0.247 | Train PPL:   1.280 | lr: 2.700e-03
# [Epoch: 3][#examples: 29632/46620][#steps: 2650]
# 	Train Loss: 0.247 | Train PPL:   1.280 | lr: 2.700e-03
# [Epoch: 3][#examples: 32832/46620][#steps: 2700]
# 	Train Loss: 0.248 | Train PPL:   1.282 | lr: 2.700e-03
# [Epoch: 3][#examples: 36032/46620][#steps: 2750]
# 	Train Loss: 0.249 | Train PPL:   1.283 | lr: 2.700e-03
# [Epoch: 3][#examples: 39232/46620][#steps: 2800]
# 	Train Loss: 0.251 | Train PPL:   1.285 | lr: 2.700e-03
# [Epoch: 3][#examples: 42432/46620][#steps: 2850]
# 	Train Loss: 0.252 | Train PPL:   1.286 | lr: 2.700e-03
# [Epoch: 3][#examples: 45632/46620][#steps: 2900]
# 	Train Loss: 0.252 | Train PPL:   1.287 | lr: 2.700e-03
# [VAL]: The number of correct predictions (main-task (multi)): 3947/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3932/5828
#
# ---------------------------------------
# [Epoch: 3][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 99/100
# 	 Val. Loss: 0.575 | Val. Acc: 0.677 | Val. PPL:   1.776
# 	 BEST. Val. Loss: 0.570 | BEST. Val. Acc: 0.677 | Val. Loss: 0.575 | BEST. Val. Epoch: 3 | BEST. Val. Step: 2916
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.675
# ---------------------------------------
#
# Epoch: 04 | Time: 1m 25s
# 	Train Loss: 0.253 | Train PPL:   1.287
# 	 Val. Loss: 0.575 | Val. Acc: 0.677 | Val. PPL:   1.776
# [Train]: Current Teacher Forcing Ratio: 0.680
# [Epoch: 4][#examples: 2176/46620][#steps: 2950]
# 	Train Loss: 0.220 | Train PPL:   1.246 | lr: 2.700e-03
# [Epoch: 4][#examples: 5376/46620][#steps: 3000]
# 	Train Loss: 0.206 | Train PPL:   1.229 | lr: 2.700e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3964/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3954/5828
#
# ---------------------------------------
# [Epoch: 4][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.552 | Val. Acc: 0.680 | Val. PPL:   1.736
# 	 BEST. Val. Loss: 0.552 | BEST. Val. Acc: 0.680 | Val. Loss: 0.552 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3000
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.678
# ---------------------------------------
#
# [Epoch: 4][#examples: 8576/46620][#steps: 3050]
# 	Train Loss: 0.202 | Train PPL:   1.224 | lr: 2.700e-03
# [Epoch: 4][#examples: 11776/46620][#steps: 3100]
# 	Train Loss: 0.206 | Train PPL:   1.229 | lr: 2.700e-03
# [Epoch: 4][#examples: 14976/46620][#steps: 3150]
# 	Train Loss: 0.207 | Train PPL:   1.231 | lr: 2.700e-03
# [Epoch: 4][#examples: 18176/46620][#steps: 3200]
# 	Train Loss: 0.207 | Train PPL:   1.229 | lr: 2.700e-03
# [Epoch: 4][#examples: 21376/46620][#steps: 3250]
# 	Train Loss: 0.209 | Train PPL:   1.232 | lr: 2.700e-03
# [Epoch: 4][#examples: 24576/46620][#steps: 3300]
# 	Train Loss: 0.210 | Train PPL:   1.234 | lr: 2.700e-03
# [Epoch: 4][#examples: 27776/46620][#steps: 3350]
# 	Train Loss: 0.213 | Train PPL:   1.238 | lr: 2.700e-03
# [Epoch: 4][#examples: 30976/46620][#steps: 3400]
# 	Train Loss: 0.216 | Train PPL:   1.241 | lr: 2.700e-03
# [Epoch: 4][#examples: 34176/46620][#steps: 3450]
# 	Train Loss: 0.218 | Train PPL:   1.244 | lr: 2.700e-03
# [Epoch: 4][#examples: 37376/46620][#steps: 3500]
# 	Train Loss: 0.221 | Train PPL:   1.247 | lr: 2.700e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3979/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3964/5828
#
# ---------------------------------------
# [Epoch: 4][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 99/100
# 	 Val. Loss: 0.563 | Val. Acc: 0.683 | Val. PPL:   1.755
# 	 BEST. Val. Loss: 0.552 | BEST. Val. Acc: 0.683 | Val. Loss: 0.563 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.680
# ---------------------------------------
#
# [Epoch: 4][#examples: 40576/46620][#steps: 3550]
# 	Train Loss: 0.222 | Train PPL:   1.249 | lr: 2.700e-03
# [Epoch: 4][#examples: 43776/46620][#steps: 3600]
# 	Train Loss: 0.223 | Train PPL:   1.250 | lr: 2.700e-03
# [VAL]: The number of correct predictions (main-task (multi)): 3939/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 3966/5828
#
# ---------------------------------------
# [Epoch: 4][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.549 | Val. Acc: 0.676 | Val. PPL:   1.731
# 	 BEST. Val. Loss: 0.549 | BEST. Val. Acc: 0.683 | Val. Loss: 0.563 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.681
# ---------------------------------------
#
# Epoch: 05 | Time: 1m 30s
# 	Train Loss: 0.224 | Train PPL:   1.251
# 	 Val. Loss: 0.549 | Val. Acc: 0.676 | Val. PPL:   1.731
# [Train]: Current Teacher Forcing Ratio: 0.650
# [Epoch: 5][#examples: 320/46620][#steps: 3650]
# 	Train Loss: 0.150 | Train PPL:   1.162 | lr: 2.430e-03
# [Epoch: 5][#examples: 3520/46620][#steps: 3700]
# 	Train Loss: 0.163 | Train PPL:   1.177 | lr: 2.430e-03
# [Epoch: 5][#examples: 6720/46620][#steps: 3750]
# 	Train Loss: 0.165 | Train PPL:   1.179 | lr: 2.430e-03
# [Epoch: 5][#examples: 9920/46620][#steps: 3800]
# 	Train Loss: 0.163 | Train PPL:   1.177 | lr: 2.430e-03
# [Epoch: 5][#examples: 13120/46620][#steps: 3850]
# 	Train Loss: 0.167 | Train PPL:   1.182 | lr: 2.430e-03
# [Epoch: 5][#examples: 16320/46620][#steps: 3900]
# 	Train Loss: 0.167 | Train PPL:   1.182 | lr: 2.430e-03
# [Epoch: 5][#examples: 19520/46620][#steps: 3950]
# 	Train Loss: 0.168 | Train PPL:   1.183 | lr: 2.430e-03
# [Epoch: 5][#examples: 22720/46620][#steps: 4000]
# 	Train Loss: 0.171 | Train PPL:   1.186 | lr: 2.430e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 3974/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4019/5828
#
# ---------------------------------------
# [Epoch: 5][Validatiing...]
# 	 Early Stopping Patience: 99/100
# 	 Val. Loss: 0.572 | Val. Acc: 0.682 | Val. PPL:   1.772
# 	 BEST. Val. Loss: 0.549 | BEST. Val. Acc: 0.683 | Val. Loss: 0.563 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.690
# ---------------------------------------
#
# [Epoch: 5][#examples: 25920/46620][#steps: 4050]
# 	Train Loss: 0.171 | Train PPL:   1.186 | lr: 2.187e-03
# [Epoch: 5][#examples: 29120/46620][#steps: 4100]
# 	Train Loss: 0.173 | Train PPL:   1.188 | lr: 2.187e-03
# [Epoch: 5][#examples: 32320/46620][#steps: 4150]
# 	Train Loss: 0.173 | Train PPL:   1.189 | lr: 2.187e-03
# [Epoch: 5][#examples: 35520/46620][#steps: 4200]
# 	Train Loss: 0.175 | Train PPL:   1.191 | lr: 2.187e-03
# [Epoch: 5][#examples: 38720/46620][#steps: 4250]
# 	Train Loss: 0.176 | Train PPL:   1.193 | lr: 2.187e-03
# [Epoch: 5][#examples: 41920/46620][#steps: 4300]
# 	Train Loss: 0.176 | Train PPL:   1.193 | lr: 2.187e-03
# [Epoch: 5][#examples: 45120/46620][#steps: 4350]
# 	Train Loss: 0.177 | Train PPL:   1.194 | lr: 2.187e-03
# [VAL]: The number of correct predictions (main-task (multi)): 4034/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4052/5828
#
# ---------------------------------------
# [Epoch: 5][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 98/100
# 	 Val. Loss: 0.565 | Val. Acc: 0.692 | Val. PPL:   1.760
# 	 BEST. Val. Loss: 0.549 | BEST. Val. Acc: 0.692 | Val. Loss: 0.565 | BEST. Val. Epoch: 5 | BEST. Val. Step: 4374
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.695
# ---------------------------------------
#
# Epoch: 06 | Time: 1m 27s
# 	Train Loss: 0.178 | Train PPL:   1.194
# 	 Val. Loss: 0.565 | Val. Acc: 0.692 | Val. PPL:   1.760
# [Train]: Current Teacher Forcing Ratio: 0.620
# [Epoch: 6][#examples: 1664/46620][#steps: 4400]
# 	Train Loss: 0.134 | Train PPL:   1.144 | lr: 2.187e-03
# [Epoch: 6][#examples: 4864/46620][#steps: 4450]
# 	Train Loss: 0.117 | Train PPL:   1.125 | lr: 2.187e-03
# [Epoch: 6][#examples: 8064/46620][#steps: 4500]
# 	Train Loss: 0.122 | Train PPL:   1.129 | lr: 2.187e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4070/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4110/5828
#
# ---------------------------------------
# [Epoch: 6][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 100/100
# 	 Val. Loss: 0.541 | Val. Acc: 0.698 | Val. PPL:   1.717
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.698 | Val. Loss: 0.541 | BEST. Val. Epoch: 6 | BEST. Val. Step: 4500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.705
# ---------------------------------------
#
# [Epoch: 6][#examples: 11264/46620][#steps: 4550]
# 	Train Loss: 0.124 | Train PPL:   1.132 | lr: 2.187e-03
# [Epoch: 6][#examples: 14464/46620][#steps: 4600]
# 	Train Loss: 0.125 | Train PPL:   1.133 | lr: 2.187e-03
# [Epoch: 6][#examples: 17664/46620][#steps: 4650]
# 	Train Loss: 0.128 | Train PPL:   1.136 | lr: 2.187e-03
# [Epoch: 6][#examples: 20864/46620][#steps: 4700]
# 	Train Loss: 0.130 | Train PPL:   1.139 | lr: 2.187e-03
# [Epoch: 6][#examples: 24064/46620][#steps: 4750]
# 	Train Loss: 0.132 | Train PPL:   1.141 | lr: 2.187e-03
# [Epoch: 6][#examples: 27264/46620][#steps: 4800]
# 	Train Loss: 0.134 | Train PPL:   1.143 | lr: 2.187e-03
# [Epoch: 6][#examples: 30464/46620][#steps: 4850]
# 	Train Loss: 0.135 | Train PPL:   1.144 | lr: 2.187e-03
# [Epoch: 6][#examples: 33664/46620][#steps: 4900]
# 	Train Loss: 0.136 | Train PPL:   1.146 | lr: 2.187e-03
# [Epoch: 6][#examples: 36864/46620][#steps: 4950]
# 	Train Loss: 0.137 | Train PPL:   1.147 | lr: 2.187e-03
# [Epoch: 6][#examples: 40064/46620][#steps: 5000]
# 	Train Loss: 0.138 | Train PPL:   1.148 | lr: 2.187e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4027/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4061/5828
#
# ---------------------------------------
# [Epoch: 6][Validatiing...]
# 	 Early Stopping Patience: 99/100
# 	 Val. Loss: 0.549 | Val. Acc: 0.691 | Val. PPL:   1.731
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.698 | Val. Loss: 0.541 | BEST. Val. Epoch: 6 | BEST. Val. Step: 4500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.705
# ---------------------------------------
#
# [Epoch: 6][#examples: 43264/46620][#steps: 5050]
# 	Train Loss: 0.140 | Train PPL:   1.150 | lr: 1.968e-03
# [Epoch: 6][#examples: 46464/46620][#steps: 5100]
# 	Train Loss: 0.140 | Train PPL:   1.151 | lr: 1.968e-03
# [VAL]: The number of correct predictions (main-task (multi)): 4035/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4101/5828
#
# ---------------------------------------
# [Epoch: 6][Validatiing...]
# 	 Early Stopping Patience: 98/100
# 	 Val. Loss: 0.544 | Val. Acc: 0.692 | Val. PPL:   1.723
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.698 | Val. Loss: 0.541 | BEST. Val. Epoch: 6 | BEST. Val. Step: 4500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.705
# ---------------------------------------
#
# Epoch: 07 | Time: 1m 34s
# 	Train Loss: 0.141 | Train PPL:   1.151
# 	 Val. Loss: 0.544 | Val. Acc: 0.692 | Val. PPL:   1.723
# [Train]: Current Teacher Forcing Ratio: 0.590
# [Epoch: 7][#examples: 3008/46620][#steps: 5150]
# 	Train Loss: 0.098 | Train PPL:   1.103 | lr: 1.771e-03
# [Epoch: 7][#examples: 6208/46620][#steps: 5200]
# 	Train Loss: 0.093 | Train PPL:   1.098 | lr: 1.771e-03
# [Epoch: 7][#examples: 9408/46620][#steps: 5250]
# 	Train Loss: 0.092 | Train PPL:   1.097 | lr: 1.771e-03
# [Epoch: 7][#examples: 12608/46620][#steps: 5300]
# 	Train Loss: 0.097 | Train PPL:   1.102 | lr: 1.771e-03
# [Epoch: 7][#examples: 15808/46620][#steps: 5350]
# 	Train Loss: 0.097 | Train PPL:   1.102 | lr: 1.771e-03
# [Epoch: 7][#examples: 19008/46620][#steps: 5400]
# 	Train Loss: 0.097 | Train PPL:   1.102 | lr: 1.771e-03
# [Epoch: 7][#examples: 22208/46620][#steps: 5450]
# 	Train Loss: 0.097 | Train PPL:   1.102 | lr: 1.771e-03
# [Epoch: 7][#examples: 25408/46620][#steps: 5500]
# 	Train Loss: 0.098 | Train PPL:   1.103 | lr: 1.771e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4085/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4120/5828
#
# ---------------------------------------
# [Epoch: 7][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 97/100
# 	 Val. Loss: 0.566 | Val. Acc: 0.701 | Val. PPL:   1.762
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.701 | Val. Loss: 0.566 | BEST. Val. Epoch: 7 | BEST. Val. Step: 5500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.707
# ---------------------------------------
#
# [Epoch: 7][#examples: 28608/46620][#steps: 5550]
# 	Train Loss: 0.099 | Train PPL:   1.104 | lr: 1.771e-03
# [Epoch: 7][#examples: 31808/46620][#steps: 5600]
# 	Train Loss: 0.100 | Train PPL:   1.105 | lr: 1.771e-03
# [Epoch: 7][#examples: 35008/46620][#steps: 5650]
# 	Train Loss: 0.101 | Train PPL:   1.106 | lr: 1.771e-03
# [Epoch: 7][#examples: 38208/46620][#steps: 5700]
# 	Train Loss: 0.101 | Train PPL:   1.106 | lr: 1.771e-03
# [Epoch: 7][#examples: 41408/46620][#steps: 5750]
# 	Train Loss: 0.101 | Train PPL:   1.107 | lr: 1.771e-03
# [Epoch: 7][#examples: 44608/46620][#steps: 5800]
# 	Train Loss: 0.102 | Train PPL:   1.108 | lr: 1.771e-03
# [VAL]: The number of correct predictions (main-task (multi)): 4047/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4112/5828
#
# ---------------------------------------
# [Epoch: 7][Validatiing...]
# 	 Early Stopping Patience: 96/100
# 	 Val. Loss: 0.568 | Val. Acc: 0.694 | Val. PPL:   1.764
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.701 | Val. Loss: 0.566 | BEST. Val. Epoch: 7 | BEST. Val. Step: 5500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.707
# ---------------------------------------
#
# Epoch: 08 | Time: 1m 26s
# 	Train Loss: 0.103 | Train PPL:   1.108
# 	 Val. Loss: 0.568 | Val. Acc: 0.694 | Val. PPL:   1.764
# [Train]: Current Teacher Forcing Ratio: 0.560
# [Epoch: 8][#examples: 1152/46620][#steps: 5850]
# 	Train Loss: 0.069 | Train PPL:   1.071 | lr: 1.594e-03
# [Epoch: 8][#examples: 4352/46620][#steps: 5900]
# 	Train Loss: 0.073 | Train PPL:   1.076 | lr: 1.594e-03
# [Epoch: 8][#examples: 7552/46620][#steps: 5950]
# 	Train Loss: 0.069 | Train PPL:   1.071 | lr: 1.594e-03
# [Epoch: 8][#examples: 10752/46620][#steps: 6000]
# 	Train Loss: 0.071 | Train PPL:   1.073 | lr: 1.594e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4088/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4137/5828
#
# ---------------------------------------
# [Epoch: 8][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 95/100
# 	 Val. Loss: 0.576 | Val. Acc: 0.701 | Val. PPL:   1.778
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.701 | Val. Loss: 0.576 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6000
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.710
# ---------------------------------------
#
# [Epoch: 8][#examples: 13952/46620][#steps: 6050]
# 	Train Loss: 0.073 | Train PPL:   1.076 | lr: 1.594e-03
# [Epoch: 8][#examples: 17152/46620][#steps: 6100]
# 	Train Loss: 0.073 | Train PPL:   1.075 | lr: 1.594e-03
# [Epoch: 8][#examples: 20352/46620][#steps: 6150]
# 	Train Loss: 0.073 | Train PPL:   1.076 | lr: 1.594e-03
# [Epoch: 8][#examples: 23552/46620][#steps: 6200]
# 	Train Loss: 0.074 | Train PPL:   1.077 | lr: 1.594e-03
# [Epoch: 8][#examples: 26752/46620][#steps: 6250]
# 	Train Loss: 0.075 | Train PPL:   1.077 | lr: 1.594e-03
# [Epoch: 8][#examples: 29952/46620][#steps: 6300]
# 	Train Loss: 0.075 | Train PPL:   1.078 | lr: 1.594e-03
# [Epoch: 8][#examples: 33152/46620][#steps: 6350]
# 	Train Loss: 0.076 | Train PPL:   1.079 | lr: 1.594e-03
# [Epoch: 8][#examples: 36352/46620][#steps: 6400]
# 	Train Loss: 0.076 | Train PPL:   1.079 | lr: 1.594e-03
# [Epoch: 8][#examples: 39552/46620][#steps: 6450]
# 	Train Loss: 0.078 | Train PPL:   1.081 | lr: 1.594e-03
# [Epoch: 8][#examples: 42752/46620][#steps: 6500]
# 	Train Loss: 0.078 | Train PPL:   1.081 | lr: 1.594e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4112/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4149/5828
#
# ---------------------------------------
# [Epoch: 8][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 94/100
# 	 Val. Loss: 0.582 | Val. Acc: 0.706 | Val. PPL:   1.790
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.706 | Val. Loss: 0.582 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.712
# ---------------------------------------
#
# [Epoch: 8][#examples: 45952/46620][#steps: 6550]
# 	Train Loss: 0.079 | Train PPL:   1.082 | lr: 1.594e-03
# [VAL]: The number of correct predictions (main-task (multi)): 4097/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4132/5828
#
# ---------------------------------------
# [Epoch: 8][Validatiing...]
# 	 Early Stopping Patience: 93/100
# 	 Val. Loss: 0.589 | Val. Acc: 0.703 | Val. PPL:   1.801
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.706 | Val. Loss: 0.582 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.712
# ---------------------------------------
#
# Epoch: 09 | Time: 1m 32s
# 	Train Loss: 0.079 | Train PPL:   1.082
# 	 Val. Loss: 0.589 | Val. Acc: 0.703 | Val. PPL:   1.801
# [Train]: Current Teacher Forcing Ratio: 0.530
# [Epoch: 9][#examples: 2496/46620][#steps: 6600]
# 	Train Loss: 0.059 | Train PPL:   1.061 | lr: 1.435e-03
# [Epoch: 9][#examples: 5696/46620][#steps: 6650]
# 	Train Loss: 0.055 | Train PPL:   1.057 | lr: 1.435e-03
# [Epoch: 9][#examples: 8896/46620][#steps: 6700]
# 	Train Loss: 0.055 | Train PPL:   1.056 | lr: 1.435e-03
# [Epoch: 9][#examples: 12096/46620][#steps: 6750]
# 	Train Loss: 0.054 | Train PPL:   1.055 | lr: 1.435e-03
# [Epoch: 9][#examples: 15296/46620][#steps: 6800]
# 	Train Loss: 0.054 | Train PPL:   1.056 | lr: 1.435e-03
# [Epoch: 9][#examples: 18496/46620][#steps: 6850]
# 	Train Loss: 0.054 | Train PPL:   1.056 | lr: 1.435e-03
# [Epoch: 9][#examples: 21696/46620][#steps: 6900]
# 	Train Loss: 0.054 | Train PPL:   1.056 | lr: 1.435e-03
# [Epoch: 9][#examples: 24896/46620][#steps: 6950]
# 	Train Loss: 0.055 | Train PPL:   1.056 | lr: 1.435e-03
# [Epoch: 9][#examples: 28096/46620][#steps: 7000]
# 	Train Loss: 0.056 | Train PPL:   1.058 | lr: 1.435e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4100/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4173/5828
#
# ---------------------------------------
# [Epoch: 9][Validatiing...]
# 	 Early Stopping Patience: 92/100
# 	 Val. Loss: 0.599 | Val. Acc: 0.704 | Val. PPL:   1.821
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.706 | Val. Loss: 0.582 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.716
# ---------------------------------------
#
# [Epoch: 9][#examples: 31296/46620][#steps: 7050]
# 	Train Loss: 0.057 | Train PPL:   1.058 | lr: 1.291e-03
# [Epoch: 9][#examples: 34496/46620][#steps: 7100]
# 	Train Loss: 0.057 | Train PPL:   1.059 | lr: 1.291e-03
# [Epoch: 9][#examples: 37696/46620][#steps: 7150]
# 	Train Loss: 0.058 | Train PPL:   1.059 | lr: 1.291e-03
# [Epoch: 9][#examples: 40896/46620][#steps: 7200]
# 	Train Loss: 0.058 | Train PPL:   1.060 | lr: 1.291e-03
# [Epoch: 9][#examples: 44096/46620][#steps: 7250]
# 	Train Loss: 0.058 | Train PPL:   1.060 | lr: 1.291e-03
# [VAL]: The number of correct predictions (main-task (multi)): 4126/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4147/5828
#
# ---------------------------------------
# [Epoch: 9][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 91/100
# 	 Val. Loss: 0.591 | Val. Acc: 0.708 | Val. PPL:   1.805
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.708 | Val. Loss: 0.591 | BEST. Val. Epoch: 9 | BEST. Val. Step: 7290
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.716
# ---------------------------------------
#
# Epoch: 10 | Time: 1m 27s
# 	Train Loss: 0.059 | Train PPL:   1.061
# 	 Val. Loss: 0.591 | Val. Acc: 0.708 | Val. PPL:   1.805
# [Train]: Current Teacher Forcing Ratio: 0.500
# [Epoch: 10][#examples: 640/46620][#steps: 7300]
# 	Train Loss: 0.042 | Train PPL:   1.043 | lr: 1.291e-03
# [Epoch: 10][#examples: 3840/46620][#steps: 7350]
# 	Train Loss: 0.042 | Train PPL:   1.042 | lr: 1.291e-03
# [Epoch: 10][#examples: 7040/46620][#steps: 7400]
# 	Train Loss: 0.038 | Train PPL:   1.039 | lr: 1.291e-03
# [Epoch: 10][#examples: 10240/46620][#steps: 7450]
# 	Train Loss: 0.039 | Train PPL:   1.040 | lr: 1.291e-03
# [Epoch: 10][#examples: 13440/46620][#steps: 7500]
# 	Train Loss: 0.039 | Train PPL:   1.040 | lr: 1.291e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4134/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4183/5828
#
# ---------------------------------------
# [Epoch: 10][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 90/100
# 	 Val. Loss: 0.614 | Val. Acc: 0.709 | Val. PPL:   1.848
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.709 | Val. Loss: 0.614 | BEST. Val. Epoch: 10 | BEST. Val. Step: 7500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.718
# ---------------------------------------
#
# [Epoch: 10][#examples: 16640/46620][#steps: 7550]
# 	Train Loss: 0.039 | Train PPL:   1.040 | lr: 1.291e-03
# [Epoch: 10][#examples: 19840/46620][#steps: 7600]
# 	Train Loss: 0.039 | Train PPL:   1.040 | lr: 1.291e-03
# [Epoch: 10][#examples: 23040/46620][#steps: 7650]
# 	Train Loss: 0.040 | Train PPL:   1.041 | lr: 1.291e-03
# [Epoch: 10][#examples: 26240/46620][#steps: 7700]
# 	Train Loss: 0.041 | Train PPL:   1.042 | lr: 1.291e-03
# [Epoch: 10][#examples: 29440/46620][#steps: 7750]
# 	Train Loss: 0.041 | Train PPL:   1.042 | lr: 1.291e-03
# [Epoch: 10][#examples: 32640/46620][#steps: 7800]
# 	Train Loss: 0.042 | Train PPL:   1.043 | lr: 1.291e-03
# [Epoch: 10][#examples: 35840/46620][#steps: 7850]
# 	Train Loss: 0.042 | Train PPL:   1.043 | lr: 1.291e-03
# [Epoch: 10][#examples: 39040/46620][#steps: 7900]
# 	Train Loss: 0.043 | Train PPL:   1.044 | lr: 1.291e-03
# [Epoch: 10][#examples: 42240/46620][#steps: 7950]
# 	Train Loss: 0.044 | Train PPL:   1.045 | lr: 1.291e-03
# [Epoch: 10][#examples: 45440/46620][#steps: 8000]
# 	Train Loss: 0.044 | Train PPL:   1.045 | lr: 1.291e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4123/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4160/5828
#
# ---------------------------------------
# [Epoch: 10][Validatiing...]
# 	 Early Stopping Patience: 89/100
# 	 Val. Loss: 0.625 | Val. Acc: 0.707 | Val. PPL:   1.869
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.709 | Val. Loss: 0.614 | BEST. Val. Epoch: 10 | BEST. Val. Step: 7500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.718
# ---------------------------------------
#
# [VAL]: The number of correct predictions (main-task (multi)): 4146/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4180/5828
#
# ---------------------------------------
# [Epoch: 10][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 88/100
# 	 Val. Loss: 0.626 | Val. Acc: 0.711 | Val. PPL:   1.870
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.711 | Val. Loss: 0.626 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8019
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.718
# ---------------------------------------
#
# Epoch: 11 | Time: 1m 33s
# 	Train Loss: 0.044 | Train PPL:   1.045
# 	 Val. Loss: 0.626 | Val. Acc: 0.711 | Val. PPL:   1.870
# [Train]: Current Teacher Forcing Ratio: 0.470
# [Epoch: 11][#examples: 1984/46620][#steps: 8050]
# 	Train Loss: 0.037 | Train PPL:   1.038 | lr: 1.162e-03
# [Epoch: 11][#examples: 5184/46620][#steps: 8100]
# 	Train Loss: 0.032 | Train PPL:   1.033 | lr: 1.162e-03
# [Epoch: 11][#examples: 8384/46620][#steps: 8150]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.162e-03
# [Epoch: 11][#examples: 11584/46620][#steps: 8200]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.162e-03
# [Epoch: 11][#examples: 14784/46620][#steps: 8250]
# 	Train Loss: 0.033 | Train PPL:   1.033 | lr: 1.162e-03
# [Epoch: 11][#examples: 17984/46620][#steps: 8300]
# 	Train Loss: 0.033 | Train PPL:   1.034 | lr: 1.162e-03
# [Epoch: 11][#examples: 21184/46620][#steps: 8350]
# 	Train Loss: 0.034 | Train PPL:   1.034 | lr: 1.162e-03
# [Epoch: 11][#examples: 24384/46620][#steps: 8400]
# 	Train Loss: 0.034 | Train PPL:   1.034 | lr: 1.162e-03
# [Epoch: 11][#examples: 27584/46620][#steps: 8450]
# 	Train Loss: 0.034 | Train PPL:   1.034 | lr: 1.162e-03
# [Epoch: 11][#examples: 30784/46620][#steps: 8500]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.162e-03
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4120/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4182/5828
#
# ---------------------------------------
# [Epoch: 11][Validatiing...]
# 	 Early Stopping Patience: 87/100
# 	 Val. Loss: 0.647 | Val. Acc: 0.707 | Val. PPL:   1.909
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.711 | Val. Loss: 0.626 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8019
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.718
# ---------------------------------------
#
# [Epoch: 11][#examples: 33984/46620][#steps: 8550]
# 	Train Loss: 0.035 | Train PPL:   1.035 | lr: 1.046e-03
# [Epoch: 11][#examples: 37184/46620][#steps: 8600]
# 	Train Loss: 0.035 | Train PPL:   1.036 | lr: 1.046e-03
# [Epoch: 11][#examples: 40384/46620][#steps: 8650]
# 	Train Loss: 0.036 | Train PPL:   1.036 | lr: 1.046e-03
# [Epoch: 11][#examples: 43584/46620][#steps: 8700]
# 	Train Loss: 0.036 | Train PPL:   1.037 | lr: 1.046e-03
# [VAL]: The number of correct predictions (main-task (multi)): 4136/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4176/5828
#
# ---------------------------------------
# [Epoch: 11][Validatiing...]
# 	 Early Stopping Patience: 86/100
# 	 Val. Loss: 0.643 | Val. Acc: 0.710 | Val. PPL:   1.902
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.711 | Val. Loss: 0.626 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8019
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.718
# ---------------------------------------
#
# Epoch: 12 | Time: 1m 26s
# 	Train Loss: 0.036 | Train PPL:   1.037
# 	 Val. Loss: 0.643 | Val. Acc: 0.710 | Val. PPL:   1.902
# [Train]: Current Teacher Forcing Ratio: 0.440
# [Epoch: 12][#examples: 128/46620][#steps: 8750]
# 	Train Loss: 0.032 | Train PPL:   1.033 | lr: 9.414e-04
# [Epoch: 12][#examples: 3328/46620][#steps: 8800]
# 	Train Loss: 0.027 | Train PPL:   1.027 | lr: 9.414e-04
# [Epoch: 12][#examples: 6528/46620][#steps: 8850]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 12][#examples: 9728/46620][#steps: 8900]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 12][#examples: 12928/46620][#steps: 8950]
# 	Train Loss: 0.026 | Train PPL:   1.027 | lr: 9.414e-04
# [Epoch: 12][#examples: 16128/46620][#steps: 9000]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4136/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4201/5828
#
# ---------------------------------------
# [Epoch: 12][Validatiing...]
# 	 Early Stopping Patience: 85/100
# 	 Val. Loss: 0.658 | Val. Acc: 0.710 | Val. PPL:   1.932
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.711 | Val. Loss: 0.626 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8019
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.721
# ---------------------------------------
#
# [Epoch: 12][#examples: 19328/46620][#steps: 9050]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 22528/46620][#steps: 9100]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 25728/46620][#steps: 9150]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 28928/46620][#steps: 9200]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 32128/46620][#steps: 9250]
# 	Train Loss: 0.025 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 35328/46620][#steps: 9300]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 38528/46620][#steps: 9350]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 41728/46620][#steps: 9400]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [Epoch: 12][#examples: 44928/46620][#steps: 9450]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 8.473e-04
# [VAL]: The number of correct predictions (main-task (multi)): 4171/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4218/5828
#
# ---------------------------------------
# [Epoch: 12][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 84/100
# 	 Val. Loss: 0.654 | Val. Acc: 0.716 | Val. PPL:   1.924
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.716 | Val. Loss: 0.654 | BEST. Val. Epoch: 12 | BEST. Val. Step: 9477
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.724
# ---------------------------------------
#
# Epoch: 13 | Time: 1m 23s
# 	Train Loss: 0.026 | Train PPL:   1.026
# 	 Val. Loss: 0.654 | Val. Acc: 0.716 | Val. PPL:   1.924
# [Train]: Current Teacher Forcing Ratio: 0.410
# [Epoch: 13][#examples: 1472/46620][#steps: 9500]
# 	Train Loss: 0.015 | Train PPL:   1.015 | lr: 8.473e-04
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4183/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4223/5828
#
# ---------------------------------------
# [Epoch: 13][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 83/100
# 	 Val. Loss: 0.661 | Val. Acc: 0.718 | Val. PPL:   1.937
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.718 | Val. Loss: 0.661 | BEST. Val. Epoch: 13 | BEST. Val. Step: 9500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.725
# ---------------------------------------
#
# [Epoch: 13][#examples: 4672/46620][#steps: 9550]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 7872/46620][#steps: 9600]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 11072/46620][#steps: 9650]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 14272/46620][#steps: 9700]
# 	Train Loss: 0.015 | Train PPL:   1.015 | lr: 8.473e-04
# [Epoch: 13][#examples: 17472/46620][#steps: 9750]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 20672/46620][#steps: 9800]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 23872/46620][#steps: 9850]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 27072/46620][#steps: 9900]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 30272/46620][#steps: 9950]
# 	Train Loss: 0.016 | Train PPL:   1.016 | lr: 8.473e-04
# [Epoch: 13][#examples: 33472/46620][#steps: 10000]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 8.473e-04
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4181/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4209/5828
#
# ---------------------------------------
# [Epoch: 13][Validatiing...]
# 	 Early Stopping Patience: 82/100
# 	 Val. Loss: 0.684 | Val. Acc: 0.717 | Val. PPL:   1.981
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.718 | Val. Loss: 0.661 | BEST. Val. Epoch: 13 | BEST. Val. Step: 9500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.725
# ---------------------------------------
#
# [Epoch: 13][#examples: 36672/46620][#steps: 10050]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 7.626e-04
# [Epoch: 13][#examples: 39872/46620][#steps: 10100]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 7.626e-04
# [Epoch: 13][#examples: 43072/46620][#steps: 10150]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 7.626e-04
# [Epoch: 13][#examples: 46272/46620][#steps: 10200]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 7.626e-04
# [VAL]: The number of correct predictions (main-task (multi)): 4158/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4207/5828
#
# ---------------------------------------
# [Epoch: 13][Validatiing...]
# 	 Early Stopping Patience: 81/100
# 	 Val. Loss: 0.699 | Val. Acc: 0.713 | Val. PPL:   2.012
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.718 | Val. Loss: 0.661 | BEST. Val. Epoch: 13 | BEST. Val. Step: 9500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.725
# ---------------------------------------
#
# Epoch: 14 | Time: 1m 33s
# 	Train Loss: 0.018 | Train PPL:   1.018
# 	 Val. Loss: 0.699 | Val. Acc: 0.713 | Val. PPL:   2.012
# [Train]: Current Teacher Forcing Ratio: 0.380
# [Epoch: 14][#examples: 2816/46620][#steps: 10250]
# 	Train Loss: 0.012 | Train PPL:   1.012 | lr: 6.863e-04
# [Epoch: 14][#examples: 6016/46620][#steps: 10300]
# 	Train Loss: 0.013 | Train PPL:   1.014 | lr: 6.863e-04
# [Epoch: 14][#examples: 9216/46620][#steps: 10350]
# 	Train Loss: 0.013 | Train PPL:   1.013 | lr: 6.863e-04
# [Epoch: 14][#examples: 12416/46620][#steps: 10400]
# 	Train Loss: 0.013 | Train PPL:   1.013 | lr: 6.863e-04
# [Epoch: 14][#examples: 15616/46620][#steps: 10450]
# 	Train Loss: 0.013 | Train PPL:   1.014 | lr: 6.863e-04
# [Epoch: 14][#examples: 18816/46620][#steps: 10500]
# 	Train Loss: 0.013 | Train PPL:   1.014 | lr: 6.863e-04
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 4188/5828
# [VAL]: The number of correct predictions (aux-task (multi)): 4235/5828
#
# ---------------------------------------
# [Epoch: 14][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 80/100
# 	 Val. Loss: 0.700 | Val. Acc: 0.719 | Val. PPL:   2.014
# 	 BEST. Val. Loss: 0.541 | BEST. Val. Acc: 0.719 | Val. Loss: 0.700 | BEST. Val. Epoch: 14 | BEST. Val. Step: 10500
# ---------------------------------------
#
# 		 Better Valid Acc on Auxiliary Task! (at least equal)
# 	BEST. Val. Acc Aux: 0.727
# ---------------------------------------
#
# [Epoch: 14][#examples: 22016/46620][#steps: 10550]
# 	Train Loss: 0.013 | Train PPL:   1.013 | lr: 6.863e-04
# [Epoch: 14][#examples: 25216/46620][#steps: 10600]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 6.863e-04
# [Epoch: 14][#examples: 28416/46620][#steps: 10650]
# ...
# [Epoch: 40][#examples: 73600/81252][#steps: 51950]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 40][#examples: 76800/81252][#steps: 52000]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 40][Validatiing...]
# 	 Early Stopping Patience: 10/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 40][#examples: 80000/81252][#steps: 52050]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 40][Validatiing...]
# 	 Early Stopping Patience: 9/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# Epoch: 41 | Time: 2m 20s
# 	Train Loss: 0.019 | Train PPL:   1.019
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# [Train]: Current Teacher Forcing Ratio: 0.200
# [Epoch: 41][#examples: 1920/81252][#steps: 52100]
# 	Train Loss: 0.021 | Train PPL:   1.022 | lr: 9.838e-08
# [Epoch: 41][#examples: 5120/81252][#steps: 52150]
# 	Train Loss: 0.021 | Train PPL:   1.021 | lr: 9.838e-08
# [Epoch: 41][#examples: 8320/81252][#steps: 52200]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 11520/81252][#steps: 52250]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 14720/81252][#steps: 52300]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 17920/81252][#steps: 52350]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 21120/81252][#steps: 52400]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 24320/81252][#steps: 52450]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 27520/81252][#steps: 52500]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 41][Validatiing...]
# 	 Early Stopping Patience: 8/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 41][#examples: 30720/81252][#steps: 52550]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 33920/81252][#steps: 52600]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 37120/81252][#steps: 52650]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 40320/81252][#steps: 52700]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 43520/81252][#steps: 52750]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 46720/81252][#steps: 52800]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 49920/81252][#steps: 52850]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 41][#examples: 53120/81252][#steps: 52900]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 56320/81252][#steps: 52950]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 59520/81252][#steps: 53000]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 41][Validatiing...]
# 	 Early Stopping Patience: 7/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 41][#examples: 62720/81252][#steps: 53050]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 65920/81252][#steps: 53100]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 69120/81252][#steps: 53150]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 72320/81252][#steps: 53200]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 75520/81252][#steps: 53250]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 41][#examples: 78720/81252][#steps: 53300]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 41][Validatiing...]
# 	 Early Stopping Patience: 6/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# Epoch: 42 | Time: 2m 16s
# 	Train Loss: 0.019 | Train PPL:   1.019
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# [Train]: Current Teacher Forcing Ratio: 0.200
# [Epoch: 42][#examples: 640/81252][#steps: 53350]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.838e-08
# [Epoch: 42][#examples: 3840/81252][#steps: 53400]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 7040/81252][#steps: 53450]
# 	Train Loss: 0.017 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 10240/81252][#steps: 53500]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 42][Validatiing...]
# 	 Early Stopping Patience: 5/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 42][#examples: 13440/81252][#steps: 53550]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 16640/81252][#steps: 53600]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 19840/81252][#steps: 53650]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 23040/81252][#steps: 53700]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 26240/81252][#steps: 53750]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 29440/81252][#steps: 53800]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 32640/81252][#steps: 53850]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 35840/81252][#steps: 53900]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 39040/81252][#steps: 53950]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 42240/81252][#steps: 54000]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 42][Validatiing...]
# 	 Early Stopping Patience: 4/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 42][#examples: 45440/81252][#steps: 54050]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 48640/81252][#steps: 54100]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 51840/81252][#steps: 54150]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 55040/81252][#steps: 54200]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 58240/81252][#steps: 54250]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 61440/81252][#steps: 54300]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 64640/81252][#steps: 54350]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 67840/81252][#steps: 54400]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 71040/81252][#steps: 54450]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 42][#examples: 74240/81252][#steps: 54500]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 42][Validatiing...]
# 	 Early Stopping Patience: 3/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 42][#examples: 77440/81252][#steps: 54550]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 42][#examples: 80640/81252][#steps: 54600]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 42][Validatiing...]
# 	 Early Stopping Patience: 2/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# Epoch: 43 | Time: 2m 18s
# 	Train Loss: 0.018 | Train PPL:   1.018
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# [Train]: Current Teacher Forcing Ratio: 0.200
# [Epoch: 43][#examples: 2560/81252][#steps: 54650]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 5760/81252][#steps: 54700]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 43][#examples: 8960/81252][#steps: 54750]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.838e-08
# [Epoch: 43][#examples: 12160/81252][#steps: 54800]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 15360/81252][#steps: 54850]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 18560/81252][#steps: 54900]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 21760/81252][#steps: 54950]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 24960/81252][#steps: 55000]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 43][Validatiing...]
# 	 Early Stopping Patience: 1/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 43][#examples: 28160/81252][#steps: 55050]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 31360/81252][#steps: 55100]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 34560/81252][#steps: 55150]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 37760/81252][#steps: 55200]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 40960/81252][#steps: 55250]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 44160/81252][#steps: 55300]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 47360/81252][#steps: 55350]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 50560/81252][#steps: 55400]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 53760/81252][#steps: 55450]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 56960/81252][#steps: 55500]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 43][Validatiing...]
# 	 Early Stopping Patience: 0/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# [Epoch: 43][#examples: 60160/81252][#steps: 55550]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 63360/81252][#steps: 55600]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 66560/81252][#steps: 55650]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 69760/81252][#steps: 55700]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 72960/81252][#steps: 55750]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 76160/81252][#steps: 55800]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.838e-08
# [Epoch: 43][#examples: 79360/81252][#steps: 55850]
# 	Train Loss: 0.018 | Train PPL:   1.019 | lr: 9.838e-08
# [VAL]: The number of correct predictions (main-task (multi)): 340/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
#
# ---------------------------------------
# [Epoch: 43][Validatiing...]
# 	 Early Stopping Patience: 0/100
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# 	 BEST. Val. Loss: 1.680 | BEST. Val. Acc: 0.665 | Val. Loss: 1.689 | BEST. Val. Epoch: 17 | BEST. Val. Step: 22500
# ---------------------------------------
#
# 	BEST. Val. Acc Aux: 0.684
# ---------------------------------------
#
# Epoch: 44 | Time: 2m 17s
# 	Train Loss: 0.018 | Train PPL:   1.019
# 	 Val. Loss: 1.698 | Val. Acc: 0.663 | Val. PPL:   5.463
# Early Stopping!
# [VAL]: The number of correct predictions (main-task (multi)): 341/513
# [VAL]: The number of correct predictions (aux-task (multi)): 341/513
# [TEST]: The number of correct predictions (main-task (multi)): 710/1000
# [TEST]: The number of correct predictions (aux-task (multi)): 734/1000
#            Loss       ACC   ACC-aux   ACC+   ACC-ACT Replaced
# Valid  1.689242  0.664717  0.664717     NA  0.684211   10/161
# Test   0.671263  0.710000  0.734000  0.718  0.729000   19/270
