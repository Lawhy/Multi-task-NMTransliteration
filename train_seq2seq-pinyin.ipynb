# %%
from mnmt.encoder import BasicEncoder
from mnmt.decoder import BasicFeedForwardDecoder
from mnmt.decoder import GreedyDecoder
from mnmt.attention import AdditiveAttention
from mnmt.decoder import BridgeLayer
from mnmt.model import Seq2Seq
from mnmt.datasets import *
from mnmt.inputter import ArgsFeeder
from mnmt.inputter import ModuleArgsFeeder
from mnmt.trainer.utils import *
from mnmt.trainer import Trainer
import sys
# Out:
# Loading DICT dataset...
# Loading the Dataset into the container...
# Field names: ['en', 'ch', 'pinyin_str', 'pinyin_char']
# Data sizes: [(Train, 46620), (Valid, 5828), (Test, 5828)]
# Loading NEWS dataset...
# Loading the Dataset into the container...
# Field names: ['en', 'ch', 'pinyin_str', 'pinyin_char']
# Data sizes: [(Train, 81252), (Valid, 513), (Test, 1000)]

# %%
def set_up_args(data_container, exp_num):
    build_vocabs(data_container, dict_min_freqs={'en': 1, 'ch': 1, 'pinyin_str': 1, 'pinyin_char': 1})
    for name, field in data_container.fields:
        if name == 'en':
            input_dim = len(field.vocab)
            src_pad_idx = field.vocab.stoi[field.pad_token]
        elif name == 'ch':
            output_dim = len(field.vocab)
            trg_pad_idx = field.vocab[field.pad_token]

    enc_args_feeder = ModuleArgsFeeder(input_dim=input_dim, embedding_dim=256, hidden_dim=512,
                                       embedding_dropout=0.1, rnn_type='LSTM',
                                       num_layers=2, rnn_dropout=0.2)
    dec_args_feeder = ModuleArgsFeeder(input_dim=output_dim, embedding_dim=128, hidden_dim=256,
                                       embedding_dropout=0.1, rnn_type='LSTM',
                                       num_layers=2, rnn_dropout=0.2)
    return ArgsFeeder(enc_args_feeder, [dec_args_feeder],
                      batch_size=64, src_pad_idx=src_pad_idx, trg_pad_idx=trg_pad_idx,
                      optim_choice='Adam', learning_rate=0.003, decay_patience=0,
                      lr_decay_factor=0.9, valid_criterion='ACC', early_stopping_patience=1000,
                      total_epochs=100, report_interval=50, exp_num=exp_num, multi_task_ratio=0, data_container=data_container,
                      src_lang='en', trg_lang='pinyin_str', auxiliary_name=None, quiet_translate=True,
                      valid_out_path=f"experiments/exp{exp_num}/valid.out", test_out_path=f"experiments/exp{exp_num}/test.out")


def test_seq2seq(args_feeder):
    decoder_args_feeder = args_feeder.decoder_args_feeders[0]
    encoder = BasicEncoder(args_feeder)
    feed_forward_decoder = \
        BasicFeedForwardDecoder(args_feeder,
                                AdditiveAttention(encoder_hidden_dim=args_feeder.encoder_args_feeder.hidden_dim,
                                                  decoder_hidden_dim=decoder_args_feeder.hidden_dim), decoder_index=0)
    bridge_layer = BridgeLayer(encoder_hidden_dim=args_feeder.encoder_args_feeder.hidden_dim,
                               decoder_hidden_dim=decoder_args_feeder.hidden_dim,
                               num_of_states=2)
    decoder = GreedyDecoder(feed_forward_decoder, bridge_layer, device=args_feeder.device)
    model = Seq2Seq(args_feeder, encoder, decoder, teacher_forcing_ratio=0.8).to(args_feeder.device)
    return model


if __name__ == '__main__':
    set_reproducibility(seed=1234)
    
    try:
        # DICT pinyin-str
        dict_dataset = DICT['data_container']
        seq2seq_args_feeder = set_up_args(dict_dataset, exp_num=500)
        seq2seq_args_feeder.trg_lang = 'pinyin_str'
        test_model = test_seq2seq(seq2seq_args_feeder)
        test_trainer = Trainer(seq2seq_args_feeder, test_model)
        test_trainer.run(burning_epoch=0)
        test_trainer.best_model_output()
        # DICT pinyin-char
        seq2seq_args_feeder = set_up_args(dict_dataset, exp_num=501)
        seq2seq_args_feeder.trg_lang = "pinyin_char"
        test_model = test_seq2seq(seq2seq_args_feeder)
        test_trainer = Trainer(seq2seq_args_feeder, test_model)
        test_trainer.run(burning_epoch=0)
        test_trainer.best_model_output()

        # NEWS pinyin-str
        news_dataset = NEWS['data_container']
        seq2seq_args_feeder = set_up_args(news_dataset, exp_num=502)
        seq2seq_args_feeder.trg_lang = 'pinyin_str'
        test_model = test_seq2seq(seq2seq_args_feeder)
        test_trainer = Trainer(seq2seq_args_feeder, test_model)
        test_trainer.run(burning_epoch=0)
        test_trainer.best_model_output()
        # NEWS pinyin-char
        seq2seq_args_feeder = set_up_args(news_dataset, exp_num=503)
        seq2seq_args_feeder.trg_lang = 'pinyin_char'
        test_model = test_seq2seq(seq2seq_args_feeder)
        test_trainer = Trainer(seq2seq_args_feeder, test_model)
        test_trainer.run(burning_epoch=0)
        test_trainer.best_model_output()
    except KeyboardInterrupt:
        print("Exiting loop")
# Out:
# The current device for PyTorch is cuda
# Seq2Seq(
#   (encoder): BasicEncoder(
#     (embedding): Sequential(
#       (0): Embedding(30, 256)
#       (1): Dropout(p=0.1, inplace=False)
#     )
#     (rnn): LSTM(256, 512, num_layers=2, dropout=0.2, bidirectional=True)
#   )
#   (decoder): GreedyDecoder(
#     (feed_forward_decoder): BasicFeedForwardDecoder(
#       (attention): AdditiveAttention(
#         (additive_mapping): Linear(in_features=1280, out_features=256, bias=True)
#         (v): Linear(in_features=256, out_features=1, bias=False)
#       )
#       (embedding): Sequential(
#         (0): Embedding(437, 128)
#         (1): Dropout(p=0.1, inplace=False)
#       )
#       (rnn): LSTM(1152, 256, num_layers=2, dropout=0.2)
#       (prediction): Sequential(
#         (0): Linear(in_features=1408, out_features=437, bias=True)
#         (1): LogSoftmax()
#       )
#     )
#     (bridge_layer): BridgeLayer(
#       (bridge_layer): ModuleList(
#         (0): Linear(in_features=1024, out_features=256, bias=True)
#         (1): Linear(in_features=1024, out_features=256, bias=True)
#       )
#     )
#   )
# )
# The model has 12,956,085 trainable parameters
# Running single-auxiliary-task experiment...
# Renew Evaluation Records in the Burning Phase...
# [Train]: Current Teacher Forcing Ratio: 0.800
# [Epoch: 0][#examples: 3200/46620][#steps: 50]
# 	Train Loss: 4.010 | Train PPL:  55.147 | lr: 3.000e-03
# [Epoch: 0][#examples: 6400/46620][#steps: 100]
# 	Train Loss: 3.777 | Train PPL:  43.677 | lr: 3.000e-03
# [Epoch: 0][#examples: 9600/46620][#steps: 150]
# 	Train Loss: 3.599 | Train PPL:  36.570 | lr: 3.000e-03
# [Epoch: 0][#examples: 12800/46620][#steps: 200]
# 	Train Loss: 3.405 | Train PPL:  30.127 | lr: 3.000e-03
# [Epoch: 0][#examples: 16000/46620][#steps: 250]
# 	Train Loss: 3.169 | Train PPL:  23.791 | lr: 3.000e-03
# [Epoch: 0][#examples: 19200/46620][#steps: 300]
# 	Train Loss: 2.922 | Train PPL:  18.572 | lr: 3.000e-03
# [Epoch: 0][#examples: 22400/46620][#steps: 350]
# 	Train Loss: 2.677 | Train PPL:  14.544 | lr: 3.000e-03
# [Epoch: 0][#examples: 25600/46620][#steps: 400]
# 	Train Loss: 2.462 | Train PPL:  11.723 | lr: 3.000e-03
# [Epoch: 0][#examples: 28800/46620][#steps: 450]
# 	Train Loss: 2.274 | Train PPL:   9.722 | lr: 3.000e-03
# [Epoch: 0][#examples: 32000/46620][#steps: 500]
# 	Train Loss: 2.114 | Train PPL:   8.279 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 3035/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 3016/5828
#
# ---------------------------------------
# [Epoch: 0][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.727 | Val. Acc: 0.521 | Val. PPL:   2.069
# 	 BEST. Val. Loss: 0.727 | BEST. Val. Acc: 0.521 | Val. Loss: 0.727 | BEST. Val. Epoch: 0 | BEST. Val. Step: 500
# ---------------------------------------
#
# [Epoch: 0][#examples: 35200/46620][#steps: 550]
# 	Train Loss: 1.975 | Train PPL:   7.208 | lr: 3.000e-03
# [Epoch: 0][#examples: 38400/46620][#steps: 600]
# 	Train Loss: 1.859 | Train PPL:   6.420 | lr: 3.000e-03
# [Epoch: 0][#examples: 41600/46620][#steps: 650]
# 	Train Loss: 1.758 | Train PPL:   5.803 | lr: 3.000e-03
# [Epoch: 0][#examples: 44800/46620][#steps: 700]
# 	Train Loss: 1.668 | Train PPL:   5.304 | lr: 3.000e-03
# [VAL]: The number of correct predictions (aux-task (single)): 3485/5828
#
# ---------------------------------------
# [Epoch: 0][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.583 | Val. Acc: 0.598 | Val. PPL:   1.792
# 	 BEST. Val. Loss: 0.583 | BEST. Val. Acc: 0.598 | Val. Loss: 0.583 | BEST. Val. Epoch: 0 | BEST. Val. Step: 729
# ---------------------------------------
#
# Epoch: 01 | Time: 0m 54s
# 	Train Loss: 1.621 | Train PPL:   5.057
# 	 Val. Loss: 0.583 | Val. Acc: 0.598 | Val. PPL:   1.792
# [Train]: Current Teacher Forcing Ratio: 0.770
# [Epoch: 1][#examples: 1344/46620][#steps: 750]
# 	Train Loss: 0.423 | Train PPL:   1.526 | lr: 3.000e-03
# [Epoch: 1][#examples: 4544/46620][#steps: 800]
# 	Train Loss: 0.428 | Train PPL:   1.534 | lr: 3.000e-03
# [Epoch: 1][#examples: 7744/46620][#steps: 850]
# 	Train Loss: 0.430 | Train PPL:   1.537 | lr: 3.000e-03
# [Epoch: 1][#examples: 10944/46620][#steps: 900]
# 	Train Loss: 0.426 | Train PPL:   1.531 | lr: 3.000e-03
# [Epoch: 1][#examples: 14144/46620][#steps: 950]
# 	Train Loss: 0.424 | Train PPL:   1.528 | lr: 3.000e-03
# [Epoch: 1][#examples: 17344/46620][#steps: 1000]
# 	Train Loss: 0.419 | Train PPL:   1.520 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 3723/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 3712/5828
#
# ---------------------------------------
# [Epoch: 1][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.529 | Val. Acc: 0.639 | Val. PPL:   1.697
# 	 BEST. Val. Loss: 0.529 | BEST. Val. Acc: 0.639 | Val. Loss: 0.529 | BEST. Val. Epoch: 1 | BEST. Val. Step: 1000
# ---------------------------------------
#
# [Epoch: 1][#examples: 20544/46620][#steps: 1050]
# 	Train Loss: 0.416 | Train PPL:   1.516 | lr: 3.000e-03
# [Epoch: 1][#examples: 23744/46620][#steps: 1100]
# 	Train Loss: 0.416 | Train PPL:   1.516 | lr: 3.000e-03
# [Epoch: 1][#examples: 26944/46620][#steps: 1150]
# 	Train Loss: 0.410 | Train PPL:   1.506 | lr: 3.000e-03
# [Epoch: 1][#examples: 30144/46620][#steps: 1200]
# 	Train Loss: 0.409 | Train PPL:   1.505 | lr: 3.000e-03
# [Epoch: 1][#examples: 33344/46620][#steps: 1250]
# 	Train Loss: 0.409 | Train PPL:   1.505 | lr: 3.000e-03
# [Epoch: 1][#examples: 36544/46620][#steps: 1300]
# 	Train Loss: 0.406 | Train PPL:   1.500 | lr: 3.000e-03
# [Epoch: 1][#examples: 39744/46620][#steps: 1350]
# 	Train Loss: 0.404 | Train PPL:   1.498 | lr: 3.000e-03
# [Epoch: 1][#examples: 42944/46620][#steps: 1400]
# 	Train Loss: 0.402 | Train PPL:   1.495 | lr: 3.000e-03
# [Epoch: 1][#examples: 46144/46620][#steps: 1450]
# 	Train Loss: 0.401 | Train PPL:   1.494 | lr: 3.000e-03
# [VAL]: The number of correct predictions (aux-task (single)): 3870/5828
#
# ---------------------------------------
# [Epoch: 1][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.466 | Val. Acc: 0.664 | Val. PPL:   1.593
# 	 BEST. Val. Loss: 0.466 | BEST. Val. Acc: 0.664 | Val. Loss: 0.466 | BEST. Val. Epoch: 1 | BEST. Val. Step: 1458
# ---------------------------------------
#
# Epoch: 02 | Time: 1m 4s
# 	Train Loss: 0.401 | Train PPL:   1.494
# 	 Val. Loss: 0.466 | Val. Acc: 0.664 | Val. PPL:   1.593
# [Train]: Current Teacher Forcing Ratio: 0.740
# [Epoch: 2][#examples: 2688/46620][#steps: 1500]
# 	Train Loss: 0.289 | Train PPL:   1.335 | lr: 3.000e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 3858/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 3878/5828
#
# ---------------------------------------
# [Epoch: 2][Validatiing...]
# 	 Early Stopping Patience: 999/1000
# 	 Val. Loss: 0.476 | Val. Acc: 0.662 | Val. PPL:   1.609
# 	 BEST. Val. Loss: 0.466 | BEST. Val. Acc: 0.664 | Val. Loss: 0.466 | BEST. Val. Epoch: 1 | BEST. Val. Step: 1458
# ---------------------------------------
#
# [Epoch: 2][#examples: 5888/46620][#steps: 1550]
# 	Train Loss: 0.287 | Train PPL:   1.332 | lr: 2.700e-03
# [Epoch: 2][#examples: 9088/46620][#steps: 1600]
# 	Train Loss: 0.282 | Train PPL:   1.326 | lr: 2.700e-03
# [Epoch: 2][#examples: 12288/46620][#steps: 1650]
# 	Train Loss: 0.286 | Train PPL:   1.332 | lr: 2.700e-03
# [Epoch: 2][#examples: 15488/46620][#steps: 1700]
# 	Train Loss: 0.290 | Train PPL:   1.337 | lr: 2.700e-03
# [Epoch: 2][#examples: 18688/46620][#steps: 1750]
# 	Train Loss: 0.292 | Train PPL:   1.339 | lr: 2.700e-03
# [Epoch: 2][#examples: 21888/46620][#steps: 1800]
# 	Train Loss: 0.294 | Train PPL:   1.342 | lr: 2.700e-03
# [Epoch: 2][#examples: 25088/46620][#steps: 1850]
# 	Train Loss: 0.296 | Train PPL:   1.344 | lr: 2.700e-03
# [Epoch: 2][#examples: 28288/46620][#steps: 1900]
# 	Train Loss: 0.294 | Train PPL:   1.342 | lr: 2.700e-03
# [Epoch: 2][#examples: 31488/46620][#steps: 1950]
# 	Train Loss: 0.299 | Train PPL:   1.349 | lr: 2.700e-03
# [Epoch: 2][#examples: 34688/46620][#steps: 2000]
# 	Train Loss: 0.299 | Train PPL:   1.348 | lr: 2.700e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 3993/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4031/5828
#
# ---------------------------------------
# [Epoch: 2][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.453 | Val. Acc: 0.685 | Val. PPL:   1.574
# 	 BEST. Val. Loss: 0.453 | BEST. Val. Acc: 0.685 | Val. Loss: 0.453 | BEST. Val. Epoch: 2 | BEST. Val. Step: 2000
# ---------------------------------------
#
# [Epoch: 2][#examples: 37888/46620][#steps: 2050]
# 	Train Loss: 0.300 | Train PPL:   1.349 | lr: 2.700e-03
# [Epoch: 2][#examples: 41088/46620][#steps: 2100]
# 	Train Loss: 0.300 | Train PPL:   1.350 | lr: 2.700e-03
# [Epoch: 2][#examples: 44288/46620][#steps: 2150]
# 	Train Loss: 0.300 | Train PPL:   1.350 | lr: 2.700e-03
# [VAL]: The number of correct predictions (aux-task (single)): 3985/5828
#
# ---------------------------------------
# [Epoch: 2][Validatiing...]
# 	 Early Stopping Patience: 999/1000
# 	 Val. Loss: 0.466 | Val. Acc: 0.684 | Val. PPL:   1.594
# 	 BEST. Val. Loss: 0.453 | BEST. Val. Acc: 0.685 | Val. Loss: 0.453 | BEST. Val. Epoch: 2 | BEST. Val. Step: 2000
# ---------------------------------------
#
# Epoch: 03 | Time: 1m 12s
# 	Train Loss: 0.300 | Train PPL:   1.350
# 	 Val. Loss: 0.466 | Val. Acc: 0.684 | Val. PPL:   1.594
# [Train]: Current Teacher Forcing Ratio: 0.710
# [Epoch: 3][#examples: 832/46620][#steps: 2200]
# 	Train Loss: 0.225 | Train PPL:   1.252 | lr: 2.430e-03
# [Epoch: 3][#examples: 4032/46620][#steps: 2250]
# 	Train Loss: 0.229 | Train PPL:   1.257 | lr: 2.430e-03
# [Epoch: 3][#examples: 7232/46620][#steps: 2300]
# 	Train Loss: 0.230 | Train PPL:   1.259 | lr: 2.430e-03
# [Epoch: 3][#examples: 10432/46620][#steps: 2350]
# 	Train Loss: 0.227 | Train PPL:   1.254 | lr: 2.430e-03
# [Epoch: 3][#examples: 13632/46620][#steps: 2400]
# 	Train Loss: 0.224 | Train PPL:   1.251 | lr: 2.430e-03
# [Epoch: 3][#examples: 16832/46620][#steps: 2450]
# 	Train Loss: 0.224 | Train PPL:   1.251 | lr: 2.430e-03
# [Epoch: 3][#examples: 20032/46620][#steps: 2500]
# 	Train Loss: 0.226 | Train PPL:   1.253 | lr: 2.430e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4044/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4027/5828
#
# ---------------------------------------
# [Epoch: 3][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.440 | Val. Acc: 0.694 | Val. PPL:   1.553
# 	 BEST. Val. Loss: 0.440 | BEST. Val. Acc: 0.694 | Val. Loss: 0.440 | BEST. Val. Epoch: 3 | BEST. Val. Step: 2500
# ---------------------------------------
#
# [Epoch: 3][#examples: 23232/46620][#steps: 2550]
# 	Train Loss: 0.227 | Train PPL:   1.255 | lr: 2.430e-03
# [Epoch: 3][#examples: 26432/46620][#steps: 2600]
# 	Train Loss: 0.229 | Train PPL:   1.258 | lr: 2.430e-03
# [Epoch: 3][#examples: 29632/46620][#steps: 2650]
# 	Train Loss: 0.231 | Train PPL:   1.259 | lr: 2.430e-03
# [Epoch: 3][#examples: 32832/46620][#steps: 2700]
# 	Train Loss: 0.233 | Train PPL:   1.262 | lr: 2.430e-03
# [Epoch: 3][#examples: 36032/46620][#steps: 2750]
# 	Train Loss: 0.234 | Train PPL:   1.264 | lr: 2.430e-03
# [Epoch: 3][#examples: 39232/46620][#steps: 2800]
# 	Train Loss: 0.235 | Train PPL:   1.264 | lr: 2.430e-03
# [Epoch: 3][#examples: 42432/46620][#steps: 2850]
# 	Train Loss: 0.236 | Train PPL:   1.266 | lr: 2.430e-03
# [Epoch: 3][#examples: 45632/46620][#steps: 2900]
# 	Train Loss: 0.236 | Train PPL:   1.266 | lr: 2.430e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4098/5828
#
# ---------------------------------------
# [Epoch: 3][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.431 | Val. Acc: 0.703 | Val. PPL:   1.539
# 	 BEST. Val. Loss: 0.431 | BEST. Val. Acc: 0.703 | Val. Loss: 0.431 | BEST. Val. Epoch: 3 | BEST. Val. Step: 2916
# ---------------------------------------
#
# Epoch: 04 | Time: 1m 5s
# 	Train Loss: 0.236 | Train PPL:   1.266
# 	 Val. Loss: 0.431 | Val. Acc: 0.703 | Val. PPL:   1.539
# [Train]: Current Teacher Forcing Ratio: 0.680
# [Epoch: 4][#examples: 2176/46620][#steps: 2950]
# 	Train Loss: 0.175 | Train PPL:   1.192 | lr: 2.430e-03
# [Epoch: 4][#examples: 5376/46620][#steps: 3000]
# 	Train Loss: 0.173 | Train PPL:   1.189 | lr: 2.430e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4084/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4073/5828
#
# ---------------------------------------
# [Epoch: 4][Validatiing...]
# 	 Early Stopping Patience: 999/1000
# 	 Val. Loss: 0.438 | Val. Acc: 0.701 | Val. PPL:   1.549
# 	 BEST. Val. Loss: 0.431 | BEST. Val. Acc: 0.703 | Val. Loss: 0.431 | BEST. Val. Epoch: 3 | BEST. Val. Step: 2916
# ---------------------------------------
#
# [Epoch: 4][#examples: 8576/46620][#steps: 3050]
# 	Train Loss: 0.172 | Train PPL:   1.188 | lr: 2.187e-03
# [Epoch: 4][#examples: 11776/46620][#steps: 3100]
# 	Train Loss: 0.174 | Train PPL:   1.190 | lr: 2.187e-03
# [Epoch: 4][#examples: 14976/46620][#steps: 3150]
# 	Train Loss: 0.176 | Train PPL:   1.192 | lr: 2.187e-03
# [Epoch: 4][#examples: 18176/46620][#steps: 3200]
# 	Train Loss: 0.176 | Train PPL:   1.192 | lr: 2.187e-03
# [Epoch: 4][#examples: 21376/46620][#steps: 3250]
# 	Train Loss: 0.178 | Train PPL:   1.195 | lr: 2.187e-03
# [Epoch: 4][#examples: 24576/46620][#steps: 3300]
# 	Train Loss: 0.180 | Train PPL:   1.198 | lr: 2.187e-03
# [Epoch: 4][#examples: 27776/46620][#steps: 3350]
# 	Train Loss: 0.181 | Train PPL:   1.199 | lr: 2.187e-03
# [Epoch: 4][#examples: 30976/46620][#steps: 3400]
# 	Train Loss: 0.182 | Train PPL:   1.200 | lr: 2.187e-03
# [Epoch: 4][#examples: 34176/46620][#steps: 3450]
# 	Train Loss: 0.184 | Train PPL:   1.202 | lr: 2.187e-03
# [Epoch: 4][#examples: 37376/46620][#steps: 3500]
# 	Train Loss: 0.186 | Train PPL:   1.204 | lr: 2.187e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4132/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4085/5828
#
# ---------------------------------------
# [Epoch: 4][Validatiing...]
# 		 Better Valid Loss! (at least equal)
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 1000/1000
# 	 Val. Loss: 0.423 | Val. Acc: 0.709 | Val. PPL:   1.526
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.709 | Val. Loss: 0.423 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3500
# ---------------------------------------
#
# [Epoch: 4][#examples: 40576/46620][#steps: 3550]
# 	Train Loss: 0.186 | Train PPL:   1.205 | lr: 2.187e-03
# [Epoch: 4][#examples: 43776/46620][#steps: 3600]
# 	Train Loss: 0.187 | Train PPL:   1.206 | lr: 2.187e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4146/5828
#
# ---------------------------------------
# [Epoch: 4][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 999/1000
# 	 Val. Loss: 0.430 | Val. Acc: 0.711 | Val. PPL:   1.537
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.711 | Val. Loss: 0.430 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3645
# ---------------------------------------
#
# Epoch: 05 | Time: 1m 13s
# 	Train Loss: 0.187 | Train PPL:   1.206
# 	 Val. Loss: 0.430 | Val. Acc: 0.711 | Val. PPL:   1.537
# [Train]: Current Teacher Forcing Ratio: 0.650
# [Epoch: 5][#examples: 320/46620][#steps: 3650]
# 	Train Loss: 0.104 | Train PPL:   1.110 | lr: 2.187e-03
# [Epoch: 5][#examples: 3520/46620][#steps: 3700]
# 	Train Loss: 0.125 | Train PPL:   1.133 | lr: 2.187e-03
# [Epoch: 5][#examples: 6720/46620][#steps: 3750]
# 	Train Loss: 0.130 | Train PPL:   1.139 | lr: 2.187e-03
# [Epoch: 5][#examples: 9920/46620][#steps: 3800]
# 	Train Loss: 0.132 | Train PPL:   1.141 | lr: 2.187e-03
# [Epoch: 5][#examples: 13120/46620][#steps: 3850]
# 	Train Loss: 0.136 | Train PPL:   1.146 | lr: 2.187e-03
# [Epoch: 5][#examples: 16320/46620][#steps: 3900]
# 	Train Loss: 0.139 | Train PPL:   1.149 | lr: 2.187e-03
# [Epoch: 5][#examples: 19520/46620][#steps: 3950]
# 	Train Loss: 0.142 | Train PPL:   1.153 | lr: 2.187e-03
# [Epoch: 5][#examples: 22720/46620][#steps: 4000]
# 	Train Loss: 0.145 | Train PPL:   1.156 | lr: 2.187e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4121/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4129/5828
#
# ---------------------------------------
# [Epoch: 5][Validatiing...]
# 	 Early Stopping Patience: 998/1000
# 	 Val. Loss: 0.473 | Val. Acc: 0.707 | Val. PPL:   1.605
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.711 | Val. Loss: 0.430 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3645
# ---------------------------------------
#
# [Epoch: 5][#examples: 25920/46620][#steps: 4050]
# 	Train Loss: 0.146 | Train PPL:   1.157 | lr: 1.968e-03
# [Epoch: 5][#examples: 29120/46620][#steps: 4100]
# 	Train Loss: 0.147 | Train PPL:   1.159 | lr: 1.968e-03
# [Epoch: 5][#examples: 32320/46620][#steps: 4150]
# 	Train Loss: 0.147 | Train PPL:   1.158 | lr: 1.968e-03
# [Epoch: 5][#examples: 35520/46620][#steps: 4200]
# 	Train Loss: 0.148 | Train PPL:   1.160 | lr: 1.968e-03
# [Epoch: 5][#examples: 38720/46620][#steps: 4250]
# 	Train Loss: 0.150 | Train PPL:   1.162 | lr: 1.968e-03
# [Epoch: 5][#examples: 41920/46620][#steps: 4300]
# 	Train Loss: 0.152 | Train PPL:   1.164 | lr: 1.968e-03
# [Epoch: 5][#examples: 45120/46620][#steps: 4350]
# 	Train Loss: 0.152 | Train PPL:   1.165 | lr: 1.968e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4143/5828
#
# ---------------------------------------
# [Epoch: 5][Validatiing...]
# 	 Early Stopping Patience: 997/1000
# 	 Val. Loss: 0.439 | Val. Acc: 0.711 | Val. PPL:   1.551
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.711 | Val. Loss: 0.430 | BEST. Val. Epoch: 4 | BEST. Val. Step: 3645
# ---------------------------------------
#
# Epoch: 06 | Time: 1m 3s
# 	Train Loss: 0.153 | Train PPL:   1.165
# 	 Val. Loss: 0.439 | Val. Acc: 0.711 | Val. PPL:   1.551
# [Train]: Current Teacher Forcing Ratio: 0.620
# [Epoch: 6][#examples: 1664/46620][#steps: 4400]
# 	Train Loss: 0.114 | Train PPL:   1.121 | lr: 1.771e-03
# [Epoch: 6][#examples: 4864/46620][#steps: 4450]
# 	Train Loss: 0.098 | Train PPL:   1.103 | lr: 1.771e-03
# [Epoch: 6][#examples: 8064/46620][#steps: 4500]
# 	Train Loss: 0.100 | Train PPL:   1.105 | lr: 1.771e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4181/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4199/5828
#
# ---------------------------------------
# [Epoch: 6][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 996/1000
# 	 Val. Loss: 0.446 | Val. Acc: 0.717 | Val. PPL:   1.562
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.717 | Val. Loss: 0.446 | BEST. Val. Epoch: 6 | BEST. Val. Step: 4500
# ---------------------------------------
#
# [Epoch: 6][#examples: 11264/46620][#steps: 4550]
# 	Train Loss: 0.097 | Train PPL:   1.102 | lr: 1.771e-03
# [Epoch: 6][#examples: 14464/46620][#steps: 4600]
# 	Train Loss: 0.098 | Train PPL:   1.103 | lr: 1.771e-03
# [Epoch: 6][#examples: 17664/46620][#steps: 4650]
# 	Train Loss: 0.100 | Train PPL:   1.105 | lr: 1.771e-03
# [Epoch: 6][#examples: 20864/46620][#steps: 4700]
# 	Train Loss: 0.101 | Train PPL:   1.106 | lr: 1.771e-03
# [Epoch: 6][#examples: 24064/46620][#steps: 4750]
# 	Train Loss: 0.102 | Train PPL:   1.107 | lr: 1.771e-03
# [Epoch: 6][#examples: 27264/46620][#steps: 4800]
# 	Train Loss: 0.103 | Train PPL:   1.108 | lr: 1.771e-03
# [Epoch: 6][#examples: 30464/46620][#steps: 4850]
# 	Train Loss: 0.103 | Train PPL:   1.109 | lr: 1.771e-03
# [Epoch: 6][#examples: 33664/46620][#steps: 4900]
# 	Train Loss: 0.105 | Train PPL:   1.111 | lr: 1.771e-03
# [Epoch: 6][#examples: 36864/46620][#steps: 4950]
# 	Train Loss: 0.106 | Train PPL:   1.112 | lr: 1.771e-03
# [Epoch: 6][#examples: 40064/46620][#steps: 5000]
# 	Train Loss: 0.107 | Train PPL:   1.113 | lr: 1.771e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4163/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4156/5828
#
# ---------------------------------------
# [Epoch: 6][Validatiing...]
# 	 Early Stopping Patience: 995/1000
# 	 Val. Loss: 0.457 | Val. Acc: 0.714 | Val. PPL:   1.580
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.717 | Val. Loss: 0.446 | BEST. Val. Epoch: 6 | BEST. Val. Step: 4500
# ---------------------------------------
#
# [Epoch: 6][#examples: 43264/46620][#steps: 5050]
# 	Train Loss: 0.108 | Train PPL:   1.114 | lr: 1.594e-03
# [Epoch: 6][#examples: 46464/46620][#steps: 5100]
# 	Train Loss: 0.109 | Train PPL:   1.115 | lr: 1.594e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4216/5828
#
# ---------------------------------------
# [Epoch: 6][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 994/1000
# 	 Val. Loss: 0.449 | Val. Acc: 0.723 | Val. PPL:   1.566
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.723 | Val. Loss: 0.449 | BEST. Val. Epoch: 6 | BEST. Val. Step: 5103
# ---------------------------------------
#
# Epoch: 07 | Time: 1m 14s
# 	Train Loss: 0.109 | Train PPL:   1.115
# 	 Val. Loss: 0.449 | Val. Acc: 0.723 | Val. PPL:   1.566
# [Train]: Current Teacher Forcing Ratio: 0.590
# [Epoch: 7][#examples: 3008/46620][#steps: 5150]
# 	Train Loss: 0.069 | Train PPL:   1.071 | lr: 1.594e-03
# [Epoch: 7][#examples: 6208/46620][#steps: 5200]
# 	Train Loss: 0.070 | Train PPL:   1.072 | lr: 1.594e-03
# [Epoch: 7][#examples: 9408/46620][#steps: 5250]
# 	Train Loss: 0.068 | Train PPL:   1.070 | lr: 1.594e-03
# [Epoch: 7][#examples: 12608/46620][#steps: 5300]
# 	Train Loss: 0.069 | Train PPL:   1.072 | lr: 1.594e-03
# [Epoch: 7][#examples: 15808/46620][#steps: 5350]
# 	Train Loss: 0.071 | Train PPL:   1.073 | lr: 1.594e-03
# [Epoch: 7][#examples: 19008/46620][#steps: 5400]
# 	Train Loss: 0.072 | Train PPL:   1.074 | lr: 1.594e-03
# [Epoch: 7][#examples: 22208/46620][#steps: 5450]
# 	Train Loss: 0.072 | Train PPL:   1.075 | lr: 1.594e-03
# [Epoch: 7][#examples: 25408/46620][#steps: 5500]
# 	Train Loss: 0.073 | Train PPL:   1.076 | lr: 1.594e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4196/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4191/5828
#
# ---------------------------------------
# [Epoch: 7][Validatiing...]
# 	 Early Stopping Patience: 993/1000
# 	 Val. Loss: 0.468 | Val. Acc: 0.720 | Val. PPL:   1.596
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.723 | Val. Loss: 0.449 | BEST. Val. Epoch: 6 | BEST. Val. Step: 5103
# ---------------------------------------
#
# [Epoch: 7][#examples: 28608/46620][#steps: 5550]
# 	Train Loss: 0.074 | Train PPL:   1.077 | lr: 1.435e-03
# [Epoch: 7][#examples: 31808/46620][#steps: 5600]
# 	Train Loss: 0.075 | Train PPL:   1.078 | lr: 1.435e-03
# [Epoch: 7][#examples: 35008/46620][#steps: 5650]
# 	Train Loss: 0.077 | Train PPL:   1.080 | lr: 1.435e-03
# [Epoch: 7][#examples: 38208/46620][#steps: 5700]
# 	Train Loss: 0.077 | Train PPL:   1.080 | lr: 1.435e-03
# [Epoch: 7][#examples: 41408/46620][#steps: 5750]
# 	Train Loss: 0.078 | Train PPL:   1.081 | lr: 1.435e-03
# [Epoch: 7][#examples: 44608/46620][#steps: 5800]
# 	Train Loss: 0.078 | Train PPL:   1.082 | lr: 1.435e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4181/5828
#
# ---------------------------------------
# [Epoch: 7][Validatiing...]
# 	 Early Stopping Patience: 992/1000
# 	 Val. Loss: 0.470 | Val. Acc: 0.717 | Val. PPL:   1.600
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.723 | Val. Loss: 0.449 | BEST. Val. Epoch: 6 | BEST. Val. Step: 5103
# ---------------------------------------
#
# Epoch: 08 | Time: 1m 2s
# 	Train Loss: 0.079 | Train PPL:   1.082
# 	 Val. Loss: 0.470 | Val. Acc: 0.717 | Val. PPL:   1.600
# [Train]: Current Teacher Forcing Ratio: 0.560
# [Epoch: 8][#examples: 1152/46620][#steps: 5850]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 1.291e-03
# [Epoch: 8][#examples: 4352/46620][#steps: 5900]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 1.291e-03
# [Epoch: 8][#examples: 7552/46620][#steps: 5950]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 1.291e-03
# [Epoch: 8][#examples: 10752/46620][#steps: 6000]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 1.291e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4230/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4234/5828
#
# ---------------------------------------
# [Epoch: 8][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 991/1000
# 	 Val. Loss: 0.489 | Val. Acc: 0.726 | Val. PPL:   1.630
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.726 | Val. Loss: 0.489 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6000
# ---------------------------------------
# [Epoch: 8][#examples: 13952/46620][#steps: 6050]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 1.291e-03
# [Epoch: 8][#examples: 17152/46620][#steps: 6100]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 1.291e-03
# [Epoch: 8][#examples: 20352/46620][#steps: 6150]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 1.291e-03
# [Epoch: 8][#examples: 23552/46620][#steps: 6200]
# 	Train Loss: 0.049 | Train PPL:   1.050 | lr: 1.291e-03
# [Epoch: 8][#examples: 26752/46620][#steps: 6250]
# 	Train Loss: 0.048 | Train PPL:   1.050 | lr: 1.291e-03
# [Epoch: 8][#examples: 29952/46620][#steps: 6300]
# 	Train Loss: 0.049 | Train PPL:   1.050 | lr: 1.291e-03
# [Epoch: 8][#examples: 33152/46620][#steps: 6350]
# 	Train Loss: 0.049 | Train PPL:   1.050 | lr: 1.291e-03
# [Epoch: 8][#examples: 36352/46620][#steps: 6400]
# 	Train Loss: 0.049 | Train PPL:   1.050 | lr: 1.291e-03
# [Epoch: 8][#examples: 39552/46620][#steps: 6450]
# 	Train Loss: 0.050 | Train PPL:   1.051 | lr: 1.291e-03
# [Epoch: 8][#examples: 42752/46620][#steps: 6500]
# 	Train Loss: 0.050 | Train PPL:   1.052 | lr: 1.291e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4232/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4219/5828
#
# ---------------------------------------
# [Epoch: 8][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 990/1000
# 	 Val. Loss: 0.502 | Val. Acc: 0.726 | Val. PPL:   1.652
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.726 | Val. Loss: 0.502 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6500
# ---------------------------------------
#
# [Epoch: 8][#examples: 45952/46620][#steps: 6550]
# 	Train Loss: 0.051 | Train PPL:   1.052 | lr: 1.291e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4254/5828
#
# ---------------------------------------
# [Epoch: 8][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 989/1000
# 	 Val. Loss: 0.493 | Val. Acc: 0.730 | Val. PPL:   1.637
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.730 | Val. Loss: 0.493 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6561
# ---------------------------------------
#
# Epoch: 09 | Time: 1m 13s
# 	Train Loss: 0.051 | Train PPL:   1.052
# 	 Val. Loss: 0.493 | Val. Acc: 0.730 | Val. PPL:   1.637
# [Train]: Current Teacher Forcing Ratio: 0.530
# [Epoch: 9][#examples: 2496/46620][#steps: 6600]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.291e-03
# [Epoch: 9][#examples: 5696/46620][#steps: 6650]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.291e-03
# [Epoch: 9][#examples: 8896/46620][#steps: 6700]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.291e-03
# [Epoch: 9][#examples: 12096/46620][#steps: 6750]
# 	Train Loss: 0.034 | Train PPL:   1.034 | lr: 1.291e-03
# [Epoch: 9][#examples: 15296/46620][#steps: 6800]
# 	Train Loss: 0.034 | Train PPL:   1.035 | lr: 1.291e-03
# [Epoch: 9][#examples: 18496/46620][#steps: 6850]
# 	Train Loss: 0.035 | Train PPL:   1.036 | lr: 1.291e-03
# [Epoch: 9][#examples: 21696/46620][#steps: 6900]
# 	Train Loss: 0.036 | Train PPL:   1.037 | lr: 1.291e-03
# [Epoch: 9][#examples: 24896/46620][#steps: 6950]
# 	Train Loss: 0.037 | Train PPL:   1.038 | lr: 1.291e-03
# [Epoch: 9][#examples: 28096/46620][#steps: 7000]
# 	Train Loss: 0.038 | Train PPL:   1.039 | lr: 1.291e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4241/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4254/5828
#
# ---------------------------------------
# [Epoch: 9][Validatiing...]
# 	 Early Stopping Patience: 988/1000
# 	 Val. Loss: 0.524 | Val. Acc: 0.728 | Val. PPL:   1.688
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.730 | Val. Loss: 0.493 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6561
# ---------------------------------------
#
# [Epoch: 9][#examples: 31296/46620][#steps: 7050]
# 	Train Loss: 0.038 | Train PPL:   1.039 | lr: 1.162e-03
# [Epoch: 9][#examples: 34496/46620][#steps: 7100]
# 	Train Loss: 0.038 | Train PPL:   1.039 | lr: 1.162e-03
# [Epoch: 9][#examples: 37696/46620][#steps: 7150]
# 	Train Loss: 0.039 | Train PPL:   1.039 | lr: 1.162e-03
# [Epoch: 9][#examples: 40896/46620][#steps: 7200]
# 	Train Loss: 0.039 | Train PPL:   1.040 | lr: 1.162e-03
# [Epoch: 9][#examples: 44096/46620][#steps: 7250]
# 	Train Loss: 0.040 | Train PPL:   1.040 | lr: 1.162e-03
# [VAL]: The number of correct predictions (aux-task (single)): 4227/5828
#
# ---------------------------------------
# [Epoch: 9][Validatiing...]
# 	 Early Stopping Patience: 987/1000
# 	 Val. Loss: 0.526 | Val. Acc: 0.725 | Val. PPL:   1.692
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.730 | Val. Loss: 0.493 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6561
# ---------------------------------------
#
# Epoch: 10 | Time: 1m 4s
# 	Train Loss: 0.040 | Train PPL:   1.041
# 	 Val. Loss: 0.526 | Val. Acc: 0.725 | Val. PPL:   1.692
# [Train]: Current Teacher Forcing Ratio: 0.500
# [Epoch: 10][#examples: 640/46620][#steps: 7300]
# 	Train Loss: 0.025 | Train PPL:   1.025 | lr: 1.046e-03
# [Epoch: 10][#examples: 3840/46620][#steps: 7350]
# 	Train Loss: 0.028 | Train PPL:   1.028 | lr: 1.046e-03
# [Epoch: 10][#examples: 7040/46620][#steps: 7400]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 1.046e-03
# [Epoch: 10][#examples: 10240/46620][#steps: 7450]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 1.046e-03
# [Epoch: 10][#examples: 13440/46620][#steps: 7500]
# 	Train Loss: 0.026 | Train PPL:   1.027 | lr: 1.046e-03
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4232/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4252/5828
#
# ---------------------------------------
# [Epoch: 10][Validatiing...]
# 	 Early Stopping Patience: 986/1000
# 	 Val. Loss: 0.533 | Val. Acc: 0.726 | Val. PPL:   1.704
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.730 | Val. Loss: 0.493 | BEST. Val. Epoch: 8 | BEST. Val. Step: 6561
# ---------------------------------------
#
# [Epoch: 10][#examples: 16640/46620][#steps: 7550]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 19840/46620][#steps: 7600]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 23040/46620][#steps: 7650]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 26240/46620][#steps: 7700]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 29440/46620][#steps: 7750]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 32640/46620][#steps: 7800]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 35840/46620][#steps: 7850]
# 	Train Loss: 0.026 | Train PPL:   1.026 | lr: 9.414e-04
# [Epoch: 10][#examples: 39040/46620][#steps: 7900]
# 	Train Loss: 0.026 | Train PPL:   1.027 | lr: 9.414e-04
# [Epoch: 10][#examples: 42240/46620][#steps: 7950]
# 	Train Loss: 0.027 | Train PPL:   1.027 | lr: 9.414e-04
# [Epoch: 10][#examples: 45440/46620][#steps: 8000]
# 	Train Loss: 0.027 | Train PPL:   1.027 | lr: 9.414e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4260/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4226/5828
#
# ---------------------------------------
# [Epoch: 10][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 985/1000
# 	 Val. Loss: 0.530 | Val. Acc: 0.731 | Val. PPL:   1.699
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.731 | Val. Loss: 0.530 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8000
# ---------------------------------------
#
# [VAL]: The number of correct predictions (aux-task (single)): 4267/5828
#
# ---------------------------------------
# [Epoch: 10][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 984/1000
# 	 Val. Loss: 0.529 | Val. Acc: 0.732 | Val. PPL:   1.697
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.732 | Val. Loss: 0.529 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8019
# ---------------------------------------
#
# Epoch: 11 | Time: 1m 12s
# 	Train Loss: 0.027 | Train PPL:   1.027
# 	 Val. Loss: 0.529 | Val. Acc: 0.732 | Val. PPL:   1.697
# [Train]: Current Teacher Forcing Ratio: 0.470
# [Epoch: 11][#examples: 1984/46620][#steps: 8050]
# 	Train Loss: 0.019 | Train PPL:   1.019 | lr: 9.414e-04
# [Epoch: 11][#examples: 5184/46620][#steps: 8100]
# 	Train Loss: 0.017 | Train PPL:   1.018 | lr: 9.414e-04
# [Epoch: 11][#examples: 8384/46620][#steps: 8150]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 9.414e-04
# [Epoch: 11][#examples: 11584/46620][#steps: 8200]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# [Epoch: 11][#examples: 14784/46620][#steps: 8250]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# [Epoch: 11][#examples: 17984/46620][#steps: 8300]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# [Epoch: 11][#examples: 21184/46620][#steps: 8350]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# [Epoch: 11][#examples: 24384/46620][#steps: 8400]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# [Epoch: 11][#examples: 27584/46620][#steps: 8450]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# [Epoch: 11][#examples: 30784/46620][#steps: 8500]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 9.414e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4256/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4269/5828
#
# ---------------------------------------
# [Epoch: 11][Validatiing...]
# 	 Early Stopping Patience: 983/1000
# 	 Val. Loss: 0.556 | Val. Acc: 0.730 | Val. PPL:   1.744
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.732 | Val. Loss: 0.529 | BEST. Val. Epoch: 10 | BEST. Val. Step: 8019
# ---------------------------------------
#
# [Epoch: 11][#examples: 33984/46620][#steps: 8550]
# 	Train Loss: 0.017 | Train PPL:   1.017 | lr: 8.473e-04
# [Epoch: 11][#examples: 37184/46620][#steps: 8600]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 8.473e-04
# [Epoch: 11][#examples: 40384/46620][#steps: 8650]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 8.473e-04
# [Epoch: 11][#examples: 43584/46620][#steps: 8700]
# 	Train Loss: 0.018 | Train PPL:   1.018 | lr: 8.473e-04
# [VAL]: The number of correct predictions (aux-task (single)): 4276/5828
#
# ---------------------------------------
# [Epoch: 11][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 982/1000
# 	 Val. Loss: 0.559 | Val. Acc: 0.734 | Val. PPL:   1.749
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.734 | Val. Loss: 0.559 | BEST. Val. Epoch: 11 | BEST. Val. Step: 8748
# ---------------------------------------
#
# Epoch: 12 | Time: 1m 5s
# 	Train Loss: 0.019 | Train PPL:   1.019
# 	 Val. Loss: 0.559 | Val. Acc: 0.734 | Val. PPL:   1.749
# [Train]: Current Teacher Forcing Ratio: 0.440
# [Epoch: 12][#examples: 128/46620][#steps: 8750]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 8.473e-04
# [Epoch: 12][#examples: 3328/46620][#steps: 8800]
# 	Train Loss: 0.013 | Train PPL:   1.014 | lr: 8.473e-04
# [Epoch: 12][#examples: 6528/46620][#steps: 8850]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 8.473e-04
# [Epoch: 12][#examples: 9728/46620][#steps: 8900]
# 	Train Loss: 0.014 | Train PPL:   1.015 | lr: 8.473e-04
# [Epoch: 12][#examples: 12928/46620][#steps: 8950]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 8.473e-04
# [Epoch: 12][#examples: 16128/46620][#steps: 9000]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 8.473e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4270/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4275/5828
#
# ---------------------------------------
# [Epoch: 12][Validatiing...]
# 	 Early Stopping Patience: 981/1000
# 	 Val. Loss: 0.567 | Val. Acc: 0.733 | Val. PPL:   1.763
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.734 | Val. Loss: 0.559 | BEST. Val. Epoch: 11 | BEST. Val. Step: 8748
# ---------------------------------------
#
# [Epoch: 12][#examples: 19328/46620][#steps: 9050]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 7.626e-04
# [Epoch: 12][#examples: 22528/46620][#steps: 9100]
# 	Train Loss: 0.013 | Train PPL:   1.014 | lr: 7.626e-04
# [Epoch: 12][#examples: 25728/46620][#steps: 9150]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 7.626e-04
# [Epoch: 12][#examples: 28928/46620][#steps: 9200]
# 	Train Loss: 0.013 | Train PPL:   1.013 | lr: 7.626e-04
# [Epoch: 12][#examples: 32128/46620][#steps: 9250]
# 	Train Loss: 0.013 | Train PPL:   1.013 | lr: 7.626e-04
# [Epoch: 12][#examples: 35328/46620][#steps: 9300]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 7.626e-04
# [Epoch: 12][#examples: 38528/46620][#steps: 9350]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 7.626e-04
# [Epoch: 12][#examples: 41728/46620][#steps: 9400]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 7.626e-04
# [Epoch: 12][#examples: 44928/46620][#steps: 9450]
# 	Train Loss: 0.014 | Train PPL:   1.014 | lr: 7.626e-04
# [VAL]: The number of correct predictions (aux-task (single)): 4281/5828
#
# ---------------------------------------
# [Epoch: 12][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 980/1000
# 	 Val. Loss: 0.568 | Val. Acc: 0.735 | Val. PPL:   1.765
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.735 | Val. Loss: 0.568 | BEST. Val. Epoch: 12 | BEST. Val. Step: 9477
# ---------------------------------------
#
# Epoch: 13 | Time: 1m 5s
# 	Train Loss: 0.014 | Train PPL:   1.014
# 	 Val. Loss: 0.568 | Val. Acc: 0.735 | Val. PPL:   1.765
# [Train]: Current Teacher Forcing Ratio: 0.410
# [Epoch: 13][#examples: 1472/46620][#steps: 9500]
# 	Train Loss: 0.013 | Train PPL:   1.013 | lr: 7.626e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4260/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4239/5828
#
# ---------------------------------------
# [Epoch: 13][Validatiing...]
# 	 Early Stopping Patience: 979/1000
# 	 Val. Loss: 0.565 | Val. Acc: 0.731 | Val. PPL:   1.759
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.735 | Val. Loss: 0.568 | BEST. Val. Epoch: 12 | BEST. Val. Step: 9477
# ---------------------------------------
#
# [Epoch: 13][#examples: 4672/46620][#steps: 9550]
# 	Train Loss: 0.011 | Train PPL:   1.011 | lr: 6.863e-04
# [Epoch: 13][#examples: 7872/46620][#steps: 9600]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 11072/46620][#steps: 9650]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 14272/46620][#steps: 9700]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 17472/46620][#steps: 9750]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 20672/46620][#steps: 9800]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 23872/46620][#steps: 9850]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 27072/46620][#steps: 9900]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 30272/46620][#steps: 9950]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 33472/46620][#steps: 10000]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4290/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4270/5828
#
# ---------------------------------------
# [Epoch: 13][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 978/1000
# 	 Val. Loss: 0.589 | Val. Acc: 0.736 | Val. PPL:   1.802
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.736 | Val. Loss: 0.589 | BEST. Val. Epoch: 13 | BEST. Val. Step: 10000
# ---------------------------------------
#
# [Epoch: 13][#examples: 36672/46620][#steps: 10050]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 39872/46620][#steps: 10100]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 43072/46620][#steps: 10150]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 13][#examples: 46272/46620][#steps: 10200]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [VAL]: The number of correct predictions (aux-task (single)): 4298/5828
#
# ---------------------------------------
# [Epoch: 13][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 977/1000
# 	 Val. Loss: 0.591 | Val. Acc: 0.737 | Val. PPL:   1.805
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.737 | Val. Loss: 0.591 | BEST. Val. Epoch: 13 | BEST. Val. Step: 10206
# ---------------------------------------
#
# Epoch: 14 | Time: 1m 12s
# 	Train Loss: 0.010 | Train PPL:   1.010
# 	 Val. Loss: 0.591 | Val. Acc: 0.737 | Val. PPL:   1.805
# [Train]: Current Teacher Forcing Ratio: 0.380
# [Epoch: 14][#examples: 2816/46620][#steps: 10250]
# 	Train Loss: 0.008 | Train PPL:   1.008 | lr: 6.863e-04
# [Epoch: 14][#examples: 6016/46620][#steps: 10300]
# 	Train Loss: 0.008 | Train PPL:   1.008 | lr: 6.863e-04
# [Epoch: 14][#examples: 9216/46620][#steps: 10350]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 6.863e-04
# [Epoch: 14][#examples: 12416/46620][#steps: 10400]
# 	Train Loss: 0.008 | Train PPL:   1.008 | lr: 6.863e-04
# [Epoch: 14][#examples: 15616/46620][#steps: 10450]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 6.863e-04
# [Epoch: 14][#examples: 18816/46620][#steps: 10500]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 6.863e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4315/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4286/5828
#
# ---------------------------------------
# [Epoch: 14][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 976/1000
# 	 Val. Loss: 0.600 | Val. Acc: 0.740 | Val. PPL:   1.822
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.740 | Val. Loss: 0.600 | BEST. Val. Epoch: 14 | BEST. Val. Step: 10500
# ---------------------------------------
#
# [Epoch: 14][#examples: 22016/46620][#steps: 10550]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 6.863e-04
# [Epoch: 14][#examples: 25216/46620][#steps: 10600]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 6.863e-04
# [Epoch: 14][#examples: 28416/46620][#steps: 10650]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 6.863e-04
# [Epoch: 14][#examples: 31616/46620][#steps: 10700]
# 	Train Loss: 0.009 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 14][#examples: 34816/46620][#steps: 10750]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 14][#examples: 38016/46620][#steps: 10800]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 14][#examples: 41216/46620][#steps: 10850]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [Epoch: 14][#examples: 44416/46620][#steps: 10900]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.863e-04
# [VAL]: The number of correct predictions (aux-task (single)): 4296/5828
#
# ---------------------------------------
# [Epoch: 14][Validatiing...]
# 	 Early Stopping Patience: 975/1000
# 	 Val. Loss: 0.595 | Val. Acc: 0.737 | Val. PPL:   1.813
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.740 | Val. Loss: 0.600 | BEST. Val. Epoch: 14 | BEST. Val. Step: 10500
# ---------------------------------------
#
# Epoch: 15 | Time: 1m 8s
# 	Train Loss: 0.010 | Train PPL:   1.010
# 	 Val. Loss: 0.595 | Val. Acc: 0.737 | Val. PPL:   1.813
# [Train]: Current Teacher Forcing Ratio: 0.350
# [Epoch: 15][#examples: 960/46620][#steps: 10950]
# 	Train Loss: 0.008 | Train PPL:   1.008 | lr: 6.177e-04
# [Epoch: 15][#examples: 4160/46620][#steps: 11000]
# 	Train Loss: 0.010 | Train PPL:   1.010 | lr: 6.177e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4288/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4262/5828
#
# ---------------------------------------
# [Epoch: 15][Validatiing...]
# 	 Early Stopping Patience: 974/1000
# 	 Val. Loss: 0.590 | Val. Acc: 0.736 | Val. PPL:   1.805
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.740 | Val. Loss: 0.600 | BEST. Val. Epoch: 14 | BEST. Val. Step: 10500
# ---------------------------------------
#
# [Epoch: 15][#examples: 7360/46620][#steps: 11050]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 10560/46620][#steps: 11100]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 13760/46620][#steps: 11150]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 16960/46620][#steps: 11200]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 20160/46620][#steps: 11250]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 23360/46620][#steps: 11300]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 26560/46620][#steps: 11350]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 29760/46620][#steps: 11400]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 32960/46620][#steps: 11450]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 36160/46620][#steps: 11500]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4319/5828
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 4266/5828
#
# ---------------------------------------
# [Epoch: 15][Validatiing...]
# 		 Better Valid Acc! (at least equal)
# 	 Early Stopping Patience: 973/1000
# 	 Val. Loss: 0.606 | Val. Acc: 0.741 | Val. PPL:   1.832
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.741 | Val. Loss: 0.606 | BEST. Val. Epoch: 15 | BEST. Val. Step: 11500
# ---------------------------------------
#
# [Epoch: 15][#examples: 39360/46620][#steps: 11550]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 42560/46620][#steps: 11600]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [Epoch: 15][#examples: 45760/46620][#steps: 11650]
# 	Train Loss: 0.009 | Train PPL:   1.009 | lr: 5.559e-04
# [VAL]: The number of correct predictions (aux-task (single)): 4308/5828
#
# ---------------------------------------
# [Epoch: 15][Validatiing...]
# 	 Early Stopping Patience: 972/1000
# 	 Val. Loss: 0.604 | Val. Acc: 0.739 | Val. PPL:   1.829
# 	 BEST. Val. Loss: 0.423 | BEST. Val. Acc: 0.741 | Val. Loss: 0.606 | BEST. Val. Epoch: 15 | BEST. Val. Step: 11500
# ---------------------------------------
#
# Epoch: 16 | Time: 1m 12s
# 	Train Loss: 0.009 | Train PPL:   1.009
# 	 Val. Loss: 0.604 | Val. Acc: 0.739 | Val. PPL:   1.829
# [Train]: Current Teacher Forcing Ratio: 0.320
# [Epoch: 16][#examples: 2304/46620][#steps: 11700]
# 	Train Loss: 0.007 | Train PPL:   1.007 | lr: 5.003e-04
# [Epoch: 16][#examples: 5504/46620][#steps: 11750]
# 	Train Loss: 0.006 | Train PPL:   1.006 | lr: 5.003e-04
# [Epoch: 16][#examples: 8704/46620][#steps: 11800]
# 	Train Loss: 0.006 | Train PPL:   1.006 | lr: 5.003e-04
# [Epoch: 16][#examples: 11904/46620][#steps: 11850]
# 	Train Loss: 0.007 | Train PPL:   1.007 | lr: 5.003e-04
# [Epoch: 16][#examples: 15104/46620][#steps: 11900]
# 	Train Loss: 0.006 | Train PPL:   1.006 | lr: 5.003e-04
# [Epoch: 16][#examples: 18304/46620][#steps: 11950]
# 	Train Loss: 0.006 | Train PPL:   1.006 | lr: 5.003e-04
# [Epoch: 16][#examples: 21504/46620][#steps: 12000]
# 	Train Loss: 0.006 | Train PPL:   1.006 | lr: 5.003e-04
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 4298/5828
# -----Tst------
# ...
# 	Train Loss: 0.048 | Train PPL:   1.050 | lr: 9.838e-08
# [Epoch: 96][#examples: 59520/81252][#steps: 122850]
# 	Train Loss: 0.049 | Train PPL:   1.050 | lr: 9.838e-08
# [Epoch: 96][#examples: 62720/81252][#steps: 122900]
# 	Train Loss: 0.048 | Train PPL:   1.050 | lr: 9.838e-08
# [Epoch: 96][#examples: 65920/81252][#steps: 122950]
# 	Train Loss: 0.048 | Train PPL:   1.050 | lr: 9.838e-08
# [Epoch: 96][#examples: 69120/81252][#steps: 123000]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 96][Validatiing...]
# 	 Early Stopping Patience: 676/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 96][#examples: 72320/81252][#steps: 123050]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 9.838e-08
# [Epoch: 96][#examples: 75520/81252][#steps: 123100]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 9.838e-08
# [Epoch: 96][#examples: 78720/81252][#steps: 123150]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
#
# ---------------------------------------
# [Epoch: 96][Validatiing...]
# 	 Early Stopping Patience: 675/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# Epoch: 97 | Time: 2m 2s
# 	Train Loss: 0.047 | Train PPL:   1.048
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# [Train]: Current Teacher Forcing Ratio: 0.200
# [Epoch: 97][#examples: 640/81252][#steps: 123200]
# 	Train Loss: 0.038 | Train PPL:   1.039 | lr: 9.838e-08
# [Epoch: 97][#examples: 3840/81252][#steps: 123250]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 7040/81252][#steps: 123300]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 10240/81252][#steps: 123350]
# 	Train Loss: 0.043 | Train PPL:   1.044 | lr: 9.838e-08
# [Epoch: 97][#examples: 13440/81252][#steps: 123400]
# 	Train Loss: 0.043 | Train PPL:   1.044 | lr: 9.838e-08
# [Epoch: 97][#examples: 16640/81252][#steps: 123450]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 19840/81252][#steps: 123500]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 97][Validatiing...]
# 	 Early Stopping Patience: 674/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 97][#examples: 23040/81252][#steps: 123550]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 26240/81252][#steps: 123600]
# 	Train Loss: 0.044 | Train PPL:   1.045 | lr: 9.838e-08
# [Epoch: 97][#examples: 29440/81252][#steps: 123650]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 32640/81252][#steps: 123700]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 97][#examples: 35840/81252][#steps: 123750]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 97][#examples: 39040/81252][#steps: 123800]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 97][#examples: 42240/81252][#steps: 123850]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 97][#examples: 45440/81252][#steps: 123900]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 97][#examples: 48640/81252][#steps: 123950]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 97][#examples: 51840/81252][#steps: 124000]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 97][Validatiing...]
# 	 Early Stopping Patience: 673/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 97][#examples: 55040/81252][#steps: 124050]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 97][#examples: 58240/81252][#steps: 124100]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 97][#examples: 61440/81252][#steps: 124150]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 97][#examples: 64640/81252][#steps: 124200]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 67840/81252][#steps: 124250]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 71040/81252][#steps: 124300]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 74240/81252][#steps: 124350]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 97][#examples: 77440/81252][#steps: 124400]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 97][#examples: 80640/81252][#steps: 124450]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
#
# ---------------------------------------
# [Epoch: 97][Validatiing...]
# 	 Early Stopping Patience: 672/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# Epoch: 98 | Time: 2m 2s
# 	Train Loss: 0.046 | Train PPL:   1.047
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# [Train]: Current Teacher Forcing Ratio: 0.200
# [Epoch: 98][#examples: 2560/81252][#steps: 124500]
# 	Train Loss: 0.036 | Train PPL:   1.037 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 98][Validatiing...]
# 	 Early Stopping Patience: 671/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 98][#examples: 5760/81252][#steps: 124550]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 8960/81252][#steps: 124600]
# 	Train Loss: 0.042 | Train PPL:   1.043 | lr: 9.838e-08
# [Epoch: 98][#examples: 12160/81252][#steps: 124650]
# 	Train Loss: 0.044 | Train PPL:   1.045 | lr: 9.838e-08
# [Epoch: 98][#examples: 15360/81252][#steps: 124700]
# 	Train Loss: 0.047 | Train PPL:   1.049 | lr: 9.838e-08
# [Epoch: 98][#examples: 18560/81252][#steps: 124750]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 21760/81252][#steps: 124800]
# 	Train Loss: 0.045 | Train PPL:   1.046 | lr: 9.838e-08
# [Epoch: 98][#examples: 24960/81252][#steps: 124850]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 28160/81252][#steps: 124900]
# 	Train Loss: 0.047 | Train PPL:   1.049 | lr: 9.838e-08
# [Epoch: 98][#examples: 31360/81252][#steps: 124950]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 34560/81252][#steps: 125000]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 98][Validatiing...]
# 	 Early Stopping Patience: 670/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 98][#examples: 37760/81252][#steps: 125050]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 40960/81252][#steps: 125100]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 44160/81252][#steps: 125150]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 47360/81252][#steps: 125200]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 50560/81252][#steps: 125250]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 53760/81252][#steps: 125300]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 56960/81252][#steps: 125350]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 60160/81252][#steps: 125400]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 63360/81252][#steps: 125450]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 66560/81252][#steps: 125500]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 98][Validatiing...]
# 	 Early Stopping Patience: 669/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 98][#examples: 69760/81252][#steps: 125550]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 98][#examples: 72960/81252][#steps: 125600]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 76160/81252][#steps: 125650]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 98][#examples: 79360/81252][#steps: 125700]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
#
# ---------------------------------------
# [Epoch: 98][Validatiing...]
# 	 Early Stopping Patience: 668/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# Epoch: 99 | Time: 2m 4s
# 	Train Loss: 0.046 | Train PPL:   1.047
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# [Train]: Current Teacher Forcing Ratio: 0.200
# [Epoch: 99][#examples: 1280/81252][#steps: 125750]
# 	Train Loss: 0.054 | Train PPL:   1.056 | lr: 9.838e-08
# [Epoch: 99][#examples: 4480/81252][#steps: 125800]
# 	Train Loss: 0.054 | Train PPL:   1.055 | lr: 9.838e-08
# [Epoch: 99][#examples: 7680/81252][#steps: 125850]
# 	Train Loss: 0.049 | Train PPL:   1.050 | lr: 9.838e-08
# [Epoch: 99][#examples: 10880/81252][#steps: 125900]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 14080/81252][#steps: 125950]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 17280/81252][#steps: 126000]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 99][Validatiing...]
# 	 Early Stopping Patience: 667/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 99][#examples: 20480/81252][#steps: 126050]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 23680/81252][#steps: 126100]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 26880/81252][#steps: 126150]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 30080/81252][#steps: 126200]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 33280/81252][#steps: 126250]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 36480/81252][#steps: 126300]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 39680/81252][#steps: 126350]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 42880/81252][#steps: 126400]
# 	Train Loss: 0.047 | Train PPL:   1.049 | lr: 9.838e-08
# [Epoch: 99][#examples: 46080/81252][#steps: 126450]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 49280/81252][#steps: 126500]
# 	Train Loss: 0.048 | Train PPL:   1.049 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 99][Validatiing...]
# 	 Early Stopping Patience: 666/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [Epoch: 99][#examples: 52480/81252][#steps: 126550]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 55680/81252][#steps: 126600]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 58880/81252][#steps: 126650]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 62080/81252][#steps: 126700]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 65280/81252][#steps: 126750]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 68480/81252][#steps: 126800]
# 	Train Loss: 0.046 | Train PPL:   1.047 | lr: 9.838e-08
# [Epoch: 99][#examples: 71680/81252][#steps: 126850]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 74880/81252][#steps: 126900]
# 	Train Loss: 0.047 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 78080/81252][#steps: 126950]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# [Epoch: 99][#examples: 81280/81252][#steps: 127000]
# 	Train Loss: 0.046 | Train PPL:   1.048 | lr: 9.838e-08
# -----Val------
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
# -----Tst------
# [TEST]: The number of correct predictions (aux-task (single)): 679/1000
#
# ---------------------------------------
# [Epoch: 99][Validatiing...]
# 	 Early Stopping Patience: 665/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# [VAL]: The number of correct predictions (aux-task (single)): 317/513
#
# ---------------------------------------
# [Epoch: 99][Validatiing...]
# 	 Early Stopping Patience: 664/1000
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# 	 BEST. Val. Loss: 1.108 | BEST. Val. Acc: 0.626 | Val. Loss: 1.539 | BEST. Val. Epoch: 16 | BEST. Val. Step: 21590
# ---------------------------------------
#
# Epoch: 100 | Time: 2m 3s
# 	Train Loss: 0.046 | Train PPL:   1.048
# 	 Val. Loss: 1.567 | Val. Acc: 0.618 | Val. PPL:   4.793
# [VAL]: The number of correct predictions (aux-task (single)): 321/513
# [TEST]: The number of correct predictions (aux-task (single)): 681/1000
#            Loss       ACC   ACC-ACT Replaced
# Valid  1.539215  0.625731  0.625731    0/135
# Test   0.939498  0.681000  0.681000    0/214
